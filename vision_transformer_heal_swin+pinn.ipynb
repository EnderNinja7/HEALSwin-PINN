# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
"""Import dependencies"""
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.models import resnet18
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# %%
class MyDatasetViT(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data = []
        self.labels = []
        self.class_names = ['axion', 'cdm', 'no_sub']
        self.transform = transform

        print(f"Loading dataset from: {data_dir}")
        print(f"Looking for classes: {self.class_names}")

        for idx, class_name in enumerate(self.class_names):
            class_dir = os.path.join(data_dir, class_name)
            print(f"--- Processing class: {class_name} ---")

            if not os.path.exists(class_dir):
                print(f"[ERROR] Directory not found: {class_dir}")
                continue

            files = os.listdir(class_dir)

            for file_name in files:
                if file_name.endswith('.npy'):
                    file_path = os.path.join(class_dir, file_name)
                    loaded_data = np.load(file_path, allow_pickle=True)

                    if class_name == 'axion':
                        image = loaded_data[0]
                    else:
                        image = loaded_data

                    # [DEBUG] Print the shape of the raw numpy array
                    print(f"  [DEBUG] Loaded '{file_name}'. Raw numpy shape: {image.shape}")

                    # Ensure the image is a 2D array (H, W) before adding channel dimension.
                    if image.ndim != 2:
                        image = np.squeeze(image)

                    # Convert to a float tensor and add a channel dimension -> [1, H, W]
                    image_tensor = torch.tensor(image, dtype=torch.float32).unsqueeze(0)

                    # [DEBUG] Print the shape of the final tensor being stored in the dataset
                    print(f"  [DEBUG] Storing tensor with final shape: {image_tensor.shape}\n")

                    self.data.append(image_tensor)
                    self.labels.append(idx)

        print("\n--- Dataset Loading Complete ---")
        print(f"Total images loaded: {len(self.data)}")

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        """
        This method is called by the DataLoader to get one item from the dataset.
        The debug prints here are CRITICAL for finding the error.
        """
        #print(f"--- Getting item index: {idx} ---")

        # Retrieve the pre-loaded tensor and its label
        image = self.data[idx]
        label = self.labels[idx]

        # [DEBUG] Print shape BEFORE the transform is applied
        #print(f"  [DEBUG] Shape of tensor BEFORE transform: {image.shape}")

        # Apply transformations (e.g., resizing) if they are provided
        if self.transform:
            image = self.transform(image)
            # [DEBUG] Print shape AFTER the transform is applied
            #print(f"  [DEBUG] Shape of tensor AFTER transform: {image.shape}")
        else:
            #print("  [DEBUG] No transform was applied.")
            pass

        return image, label

# %%
# Import the transforms module
from torchvision import transforms
# Hyperparameters
batch_size = 32
learning_rate = 0.001
num_epochs = 100

# Data Directories
train_dir = '/content/drive/MyDrive/Model_III_dataset/Model_III'
#val_dir = '../dataset/dataset/val'

print(f"Training Directory: {train_dir}")
#print(f"Validation Directory: {val_dir}")

vit_transforms = transforms.Compose([
    # transforms.ToTensor(), # Removed ToTensor()
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomRotation(degrees=90), # Can be any angle range
])

# Create Datasets and Dataloaders
#train_dataset = MyDataset(train_dir)
#val_dataset = MyDataset(val_dir)
#dataset = MyDatasetViT(train_dir, vit_transforms)
#train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(dataset, [0.75, 0.15, 0.1])

#train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
#val_loader = DataLoader(val_dataset, batch_size=batch_size, num_workers=4, pin_memory=True)

#print(f"Batch Size: {batch_size}")
#print(f"Number of Training Batches: {len(train_loader)}")
#print(f"Number of Validation Batches: {len(val_loader)}")

#Save the dataloader so that we don't have to bear with this pain again
#torch.save(train_loader, '/content/drive/MyDrive/Model_III_dataset/train_loader.pth')
#torch.save(val_loader, '/content/drive/MyDrive/Model_III_dataset/val_loader.pth')
# Out:
# Training Directory: /content/drive/MyDrive/Model_III_dataset/Model_III

# %%
#import data loaders from file
train_loader = torch.load('/content/drive/MyDrive/model_alpha/vit_train_loader.pth', weights_only=False)
val_loader = torch.load('/content/drive/MyDrive/model_alpha/vit_val_loader.pth', weights_only=False)

# %%
"""
This implementation of the SWIN Transformer was adapted from the SWIN-UNet at
https://github.com/HuCaoFighting/Swin-Unet/blob/main/networks/swin_transformer_unet_skip_expand_decoder_sys.py
and modified for image classification tasks on specific input dimensions.

The RelativisticPhysicalInformedEncoder has been added to the HEAL-Swin model.
"""

from dataclasses import dataclass, field
from typing import Optional, List, Literal, Union, Tuple

import torch
import torch.nn as nn
import torch.utils.checkpoint as checkpoint
from timm.models.layers import DropPath, trunc_normal_
from torch import Tensor


class Mlp(nn.Module):
    """ Multi-Layer Perceptron """
    def __init__(
        self,
        in_features,
        hidden_features=None,
        out_features=None,
        act_layer=nn.GELU,
        drop=0.0,
    ):
        super().__init__()
        out_features = out_features or in_features
        hidden_features = hidden_features or in_features
        self.fc1 = nn.Linear(in_features, hidden_features)
        self.act = act_layer()
        self.fc2 = nn.Linear(hidden_features, out_features)
        self.drop = nn.Dropout(drop)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act(x)
        x = self.drop(x)
        x = self.fc2(x)
        x = self.drop(x)
        return x


def window_partition(x, window_size):
    """
    Partitions the input tensor into non-overlapping windows.
    Args:
        x: (B, H, W, C)
        window_size (tuple[int]): Window size (height, width).

    Returns:
        windows: (num_windows*B, window_size, window_size, C)
    """
    B, H, W, C = x.shape
    x = x.view(B, H // window_size[0], window_size[0], W // window_size[1], window_size[1], C)
    windows = x.permute(0, 1, 3, 2, 4, 5).contiguous().view(-1, window_size[0], window_size[1], C)
    return windows


def window_reverse(windows, window_size, H, W):
    """
    Reverses the window partitioning.
    Args:
        windows: (num_windows*B, window_size, window_size, C)
        window_size (tuple[int]): Window size (height, width).
        H (int): Height of image.
        W (int): Width of image.

    Returns:
        x: (B, H, W, C)
    """
    B = int(windows.shape[0] / (H * W / window_size[0] / window_size[1]))
    x = windows.view(
        B, H // window_size[0], W // window_size[1], window_size[0], window_size[1], -1
    )
    x = x.permute(0, 1, 3, 2, 4, 5).contiguous().view(B, H, W, -1)
    return x


class WindowAttention(nn.Module):
    r""" Window based multi-head self attention (W-MSA) module with relative position bias.
    It supports both shifted and non-shifted windows.
    """

    def __init__(
        self,
        dim,
        window_size,
        num_heads,
        qkv_bias=True,
        qk_scale=None,
        attn_drop=0.0,
        proj_drop=0.0,
    ):
        super().__init__()
        self.dim = dim
        self.window_size = window_size
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = qk_scale or head_dim**-0.5

        # Define a parameter table of relative position bias
        self.relative_position_bias_table = nn.Parameter(
            torch.zeros((2 * window_size[0] - 1) * (2 * window_size[1] - 1), num_heads)
        )

        # Get pair-wise relative position index for each token inside the window
        coords_h = torch.arange(self.window_size[0])
        coords_w = torch.arange(self.window_size[1])
        coords = torch.stack(torch.meshgrid([coords_h, coords_w], indexing="ij"))
        coords_flatten = torch.flatten(coords, 1)
        relative_coords = coords_flatten[:, :, None] - coords_flatten[:, None, :]
        relative_coords = relative_coords.permute(1, 2, 0).contiguous()
        relative_coords[:, :, 0] += self.window_size[0] - 1
        relative_coords[:, :, 1] += self.window_size[1] - 1
        relative_coords[:, :, 0] *= 2 * self.window_size[1] - 1
        relative_position_index = relative_coords.sum(-1)
        self.register_buffer("relative_position_index", relative_position_index)

        self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
        self.attn_drop = nn.Dropout(attn_drop)
        self.proj = nn.Linear(dim, dim)
        self.proj_drop = nn.Dropout(proj_drop)

        trunc_normal_(self.relative_position_bias_table, std=0.02)
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, x, mask=None):
        B_, N, C = x.shape
        qkv = self.qkv(x).reshape(B_, N, 3, self.num_heads, C // self.num_heads).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        q = q * self.scale
        attn = q @ k.transpose(-2, -1)

        relative_position_bias = self.relative_position_bias_table[
            self.relative_position_index.view(-1)
        ].view(
            self.window_size[0] * self.window_size[1],
            self.window_size[0] * self.window_size[1],
            -1,
        )
        relative_position_bias = relative_position_bias.permute(2, 0, 1).contiguous()
        attn = attn + relative_position_bias.unsqueeze(0)

        if mask is not None:
            nW = mask.shape[0]
            attn = attn.view(B_ // nW, nW, self.num_heads, N, N) + mask.unsqueeze(1).unsqueeze(0)
            attn = attn.view(-1, self.num_heads, N, N)
            attn = self.softmax(attn)
        else:
            attn = self.softmax(attn)

        attn = self.attn_drop(attn)

        x = (attn @ v).transpose(1, 2).reshape(B_, N, C)
        x = self.proj(x)
        x = self.proj_drop(x)
        return x

class TransformerLSABlock(nn.Module):
    """
    A Transformer block with LayerNorm, Multi-Head Self-Attention, and a Feed-Forward Network.
    This is a standard component for transformer architectures.
    """
    def __init__(self, embed_dim, num_heads, num_patches, num_hidden_neurons, activation_function, device, dropout):
        super(TransformerLSABlock, self).__init__()
        self.norm1 = nn.LayerNorm(embed_dim)
        self.attn = nn.MultiheadAttention(embed_dim, num_heads, dropout=dropout, batch_first=True)
        self.norm2 = nn.LayerNorm(embed_dim)
        self.mlp = nn.Sequential(
            nn.Linear(embed_dim, num_hidden_neurons),
            activation_function(),
            nn.Dropout(dropout),
            nn.Linear(num_hidden_neurons, embed_dim),
            nn.Dropout(dropout)
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # Multi-Head Self-Attention
        x_norm = self.norm1(x)
        attn_output, _ = self.attn(x_norm, x_norm, x_norm)
        x = x + self.dropout(attn_output)

        # Feed-Forward Network
        x_norm = self.norm2(x)
        mlp_output = self.mlp(x_norm)
        x = x + self.dropout(mlp_output)
        return x

class SwinTransformerBlock(nn.Module):
    r""" Swin Transformer Block."""

    def __init__(
        self,
        dim,
        input_resolution,
        num_heads,
        window_size=(5, 5),
        shift_size=(0, 0),
        mlp_ratio=4.0,
        qkv_bias=True,
        qk_scale=None,
        drop=0.0,
        attn_drop=0.0,
        drop_path=0.0,
        act_layer=nn.GELU,
        norm_layer=nn.LayerNorm,
    ):
        super().__init__()
        self.dim = dim
        self.input_resolution = input_resolution
        self.num_heads = num_heads
        self.window_size = window_size
        self.shift_size = shift_size
        self.mlp_ratio = mlp_ratio

        if min(self.input_resolution) <= min(self.window_size):
            self.shift_size = (0, 0)
            self.window_size = self.input_resolution

        assert 0 <= self.shift_size[0] < self.window_size[0], "shift_size must be less than window_size"
        assert 0 <= self.shift_size[1] < self.window_size[1], "shift_size must be less than window_size"

        self.norm1 = norm_layer(dim)
        self.attn = WindowAttention(
            dim,
            window_size=self.window_size,
            num_heads=num_heads,
            qkv_bias=qkv_bias,
            qk_scale=qk_scale,
            attn_drop=attn_drop,
            proj_drop=drop,
        )

        self.drop_path = DropPath(drop_path) if drop_path > 0.0 else nn.Identity()
        self.norm2 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp(
            in_features=dim,
            hidden_features=mlp_hidden_dim,
            act_layer=act_layer,
            drop=drop,
        )

        if self.shift_size[0] > 0 or self.shift_size[1] > 0:
            H, W = self.input_resolution
            img_mask = torch.zeros((1, H, W, 1))
            h_slices = (
                slice(0, -self.window_size[0]),
                slice(-self.window_size[0], -self.shift_size[0]),
                slice(-self.shift_size[0], None),
            )
            w_slices = (
                slice(0, -self.window_size[1]),
                slice(-self.window_size[1], -self.shift_size[1]),
                slice(-self.shift_size[1], None),
            )
            cnt = 0
            for h in h_slices:
                for w in w_slices:
                    img_mask[:, h, w, :] = cnt
                    cnt += 1

            mask_windows = window_partition(img_mask, self.window_size)
            mask_windows = mask_windows.view(-1, self.window_size[0] * self.window_size[1])
            attn_mask = mask_windows.unsqueeze(1) - mask_windows.unsqueeze(2)
            attn_mask = attn_mask.masked_fill(attn_mask != 0, float(-100.0)).masked_fill(
                attn_mask == 0, float(0.0)
            )
        else:
            attn_mask = None

        self.register_buffer("attn_mask", attn_mask)

    def forward(self, x):
        H, W = self.input_resolution
        B, L, C = x.shape
        assert L == H * W, "input feature has wrong size"

        shortcut = x
        x = self.norm1(x)
        x = x.view(B, H, W, C)

        if self.shift_size[0] > 0 or self.shift_size[1] > 0:
            shifted_x = torch.roll(x, shifts=(-self.shift_size[0], -self.shift_size[1]), dims=(1, 2))
        else:
            shifted_x = x

        x_windows = window_partition(shifted_x, self.window_size)
        x_windows = x_windows.view(-1, self.window_size[0] * self.window_size[1], C)

        attn_windows = self.attn(x_windows, mask=self.attn_mask)

        attn_windows = attn_windows.view(-1, self.window_size[0], self.window_size[1], C)
        shifted_x = window_reverse(attn_windows, self.window_size, H, W)

        if self.shift_size[0] > 0 or self.shift_size[1] > 0:
            x = torch.roll(shifted_x, shifts=(self.shift_size[0], self.shift_size[1]), dims=(1, 2))
        else:
            x = shifted_x
        x = x.view(B, H * W, C)

        x = shortcut + self.drop_path(x)
        x = x + self.drop_path(self.mlp(self.norm2(x)))

        return x


class BasicLayer(nn.Module):
    """ A basic Swin Transformer layer for one stage. """

    def __init__(
        self,
        dim,
        input_resolution,
        depth,
        num_heads,
        window_size,
        mlp_ratio=4.0,
        qkv_bias=True,
        qk_scale=None,
        drop=0.0,
        attn_drop=0.0,
        drop_path=0.0,
        norm_layer=nn.LayerNorm,
        downsample=None,
    ):
        super().__init__()
        self.dim = dim
        self.input_resolution = input_resolution
        self.depth = depth

        self.blocks = nn.ModuleList(
            [
                SwinTransformerBlock(
                    dim=dim,
                    input_resolution=input_resolution,
                    num_heads=num_heads,
                    window_size=window_size,
                    shift_size=(0, 0) if (i % 2 == 0) else (window_size[0] // 2, window_size[1] // 2),
                    mlp_ratio=mlp_ratio,
                    qkv_bias=qkv_bias,
                    qk_scale=qk_scale,
                    drop=drop,
                    attn_drop=attn_drop,
                    drop_path=drop_path[i] if isinstance(drop_path, list) else drop_path,
                    norm_layer=norm_layer,
                )
                for i in range(depth)
            ]
        )

        if downsample is not None:
            self.downsample = downsample(input_resolution, dim=dim, norm_layer=norm_layer)
        else:
            self.downsample = None

    def forward(self, x):
        for blk in self.blocks:
            x = blk(x)
        if self.downsample is not None:
            x = self.downsample(x)
        return x


class PatchEmbed(nn.Module):
    r""" Image to Patch Embedding """

    def __init__(self, img_size=(150, 150), patch_size=(10, 10), in_chans=1, embed_dim=96, norm_layer=None):
        super().__init__()
        self.img_size = img_size
        self.patch_size = patch_size
        self.patches_resolution = [img_size[0] // patch_size[0], img_size[1] // patch_size[1]]
        self.num_patches = self.patches_resolution[0] * self.patches_resolution[1]
        self.in_chans = in_chans
        self.embed_dim = embed_dim

        self.proj = nn.Conv2d(in_chans, embed_dim, kernel_size=patch_size, stride=patch_size)
        if norm_layer is not None:
            self.norm = norm_layer(embed_dim)
        else:
            self.norm = None

    def forward(self, x):
        B, C, H, W = x.shape
        assert H == self.img_size[0] and W == self.img_size[1], \
            f"Input image size ({H}*{W}) doesn't match model ({self.img_size[0]}*{self.img_size[1]})."
        x = self.proj(x).flatten(2).transpose(1, 2)
        if self.norm is not None:
            x = self.norm(x)
        return x

class RelativisticPhysicalInformedEncoder(nn.Module):
    """
    A PyTorch module to perform inverse gravitational lensing using the Singular Isothermal Sphere (SIS) model.

    Attributes:
        pixel_scale (float): The scale of each pixel in the image, often in arcseconds per pixel.
        profile_size (int): The size of the image profile.
        half_profile_size (int): Half of the profile size.
        num_patches (int): Number of patches.
        embed_dim (int): Dimension of the embedding.
        num_heads (int): Number of heads in the transformer.
        num_hidden_neurons (int): Number of hidden neurons.
        eps (float): Float number used to avoid division by zero.
        transformer_activation_function (nn.Module): Activation function used in the transformer.
        num_transformer_blocks (int): Number of transformer blocks.
        device (torch.device): Device to which tensors will be moved.
        transformer (nn.ModuleList): List of transformer blocks.
        num_neurons_flatten (int): Number of neurons in the Flatten layer.
        grid_x (Tensor): Grid of x coordinates.
        grid_y (Tensor): Grid of y coordinates.
        flat_grid_x (Tensor): Flattened grid of x coordinates.
        flat_grid_y (Tensor): Flattened grid of y coordinates.
    """
    def __init__( self,
                  image_size: int,
                  patch_size: int ,
                  embed_dim: int,
                  num_patches: int,
                  num_heads: int,
                  num_hidden_neurons: int,
                  transformer_activation_function: nn.Module,
                  num_transformer_blocks: int,
                  device: torch.device,
                  dropout: float = 0.1,
                  pixel_scale:float =0.101,
                  k_min: float = 0.8,
                  k_max: float = 1.2,
                  eps: float = 1e-8
                  ):


        """
        Initialize the module.

        Args:
            image_size (int): The size of the image.
            patch_size (int): The size of each patch.
            embed_dim (int): The embedding dimension.
            num_patches (int): The number of patches.
            num_heads (int): The number of heads in the transformer.
            num_hidden_neurons (int): The number of hidden neurons.
            transformer_activation_function (nn.Module): The activation function used in the transformer.
            num_transformer_blocks (int): The number of transformer blocks.
            device (torch.device): The device to which tensors will be moved.
            dropout (float, optional): The dropout rate. Defaults to 0.1.
            pixel_scale (float, optional): The scale of each pixel in the image, often in arcseconds per pixel. Defaults to 0.101.
            k_min (float, optional): Minimum value of the potential correction parameter.  Defaults to 0.8.
            k_max (float, optional): Maximum value of the potencial correction parameter.  Defaults to 1.2.
            eps (float): Float number used to avoid division by zero. Defaluts to 1e-8.
        """

        super(RelativisticPhysicalInformedEncoder, self).__init__()

        # Initialize variables
        self.pixel_scale = pixel_scale
        self.profile_size = image_size
        self.half_profile_size = self.profile_size // 2
        self.num_patches = num_patches
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.num_hidden_neurons = num_hidden_neurons
        self.transformer_activation_function = transformer_activation_function
        self.num_transformer_blocks = num_transformer_blocks
        self.device = device
        self.k_min = k_min
        self.k_max = k_max
        self.eps = eps

        # Create an empty list for the transformer blocks
        self.transformer = nn.ModuleList()

        # Calculate the number of neurons for the Flatten layer
        self.num_neurons_flatten = (self.num_patches)*embed_dim

        # Create a for loop that iterates over the number of transformer blocks
        for _ in range(num_transformer_blocks):
          # Add a TransformerLSABlock to the transformer list
          self.transformer.append(

              TransformerLSABlock(embed_dim,
                                  num_heads,
                                  self.num_patches,
                                  num_hidden_neurons,
                                  transformer_activation_function,
                                  device,
                                  dropout)
          )

        # Create a compressor (FeedFoward) compress the size of num_neurons_flatten
        self.transformer.append(nn.Flatten())
        self.transformer.append(nn.Linear(self.num_neurons_flatten,self.profile_size*self.profile_size))
        self.transformer.append(nn.Sigmoid())

        # Create a grid for image coordinates
        x_coordinates = torch.linspace(-self.half_profile_size, self.half_profile_size-1, self.profile_size) * self.pixel_scale
        y_coordinates = torch.linspace(-self.half_profile_size, self.half_profile_size-1, self.profile_size) * self.pixel_scale
        self.grid_x, self.grid_y = torch.meshgrid(x_coordinates, y_coordinates, indexing='ij')
        self.flat_grid_x = self.grid_x.flatten().to(self.device)
        self.flat_grid_y = self.grid_y.flatten().to(self.device)


    def forward(self, input_images: Tensor, patches: Tensor)->Tensor:

        """
        Forward pass through the module.

        Args:
            input_images (torch.Tensor): The input images.
            patches (torch.Tensor): The patches extracted from the images.

        Returns:
            output_images (torch.Tensor): The output images after inverse gravitational lensing.
        """

        # Get the batch size from the input images
        batch_size = input_images.shape[0]

        # Generate k using the sequential model
        k_sigmoid = patches
        for layer in self.transformer:
            k_sigmoid = layer(k_sigmoid)

        # Reshape k_sigmoid to have shape [batch_size, profile_size, profile_size]
        k_sigmoid = k_sigmoid.view(-1, self.profile_size, self.profile_size)

        # Flatten k_sigmoid to match the shape of non_zero_x and non_zero_radius
        k_sigmoid_flat = k_sigmoid.view(-1, self.profile_size*self.profile_size)

        # Bias and Scalling
        k_sigmoid_flat = self.k_min + (self.k_max-self.k_min)*k_sigmoid_flat

         # Flatten the input images for easier indexing
        flat_input_images = input_images.view(batch_size, -1)

        # Create a mask for non-zero coordinates in the grid
        non_zero_mask = (self.flat_grid_x != 0) | (self.flat_grid_y != 0)

        # Select only the non-zero indices to match with non_zero_x and non_zero_radius
        k_sigmoid_non_zero = k_sigmoid_flat[:, non_zero_mask]

        # Get the shape of k_sigmoid_non_zero
        shape_k_sigmoid_non_zero = k_sigmoid_non_zero.shape

        # Reshape k to have a batch dimension compatible for broadcasting
        k = k_sigmoid_non_zero.view(shape_k_sigmoid_non_zero[0], 1, 1, shape_k_sigmoid_non_zero[1])

        # Apply the mask to get non-zero coordinates
        non_zero_x = self.flat_grid_x[non_zero_mask]
        non_zero_y = self.flat_grid_y[non_zero_mask]

        # Calculate the radius for non-zero coordinates
        non_zero_radius = torch.sqrt(non_zero_x ** 2 + non_zero_y ** 2)

        # Expand dimensions for broadcasting
        non_zero_radius = non_zero_radius[None, None, None, :]

        # Compute shifted coordinates based on the Gravitational Lens Equation to SIS model
        shifted_x = (non_zero_x[None, None, None, :] - k * non_zero_x[None, None, None, :] / (non_zero_radius + self.eps) )
        shifted_y = (non_zero_y[None, None, None, :] - k * non_zero_y[None, None, None, :] / (non_zero_radius + self.eps) )

        # Convert shifted coordinates to indices in the image grid
        shifted_x_idx = torch.round(shifted_x / self.pixel_scale + self.half_profile_size).long()
        shifted_y_idx = torch.round(shifted_y / self.pixel_scale + self.half_profile_size).long()

        # Clamp indices to be within the valid range
        shifted_x_idx = torch.clamp(shifted_x_idx, 0, self.profile_size - 1)
        shifted_y_idx = torch.clamp(shifted_y_idx, 0, self.profile_size - 1)


        # Initialize the output image tensor and flatten it
        output_images = torch.zeros(batch_size, self.profile_size, self.profile_size).to(self.device)
        flat_output_images = output_images.view(batch_size, -1)

        # Calculate 1D indices from shifted_x_idx and shifted_y_idx
        one_d_indices = shifted_x_idx * self.profile_size + shifted_y_idx

        # Flatten the input images for easier indexing
        flat_input_images = input_images.view(batch_size, -1)

        # Get the current values at the shifted positions in the flat output images
        output_values_at_shifted_positions = flat_output_images.gather(1, one_d_indices.view(batch_size, -1))

        # Get the corresponding values from the original positions in the flat input images
        input_values_at_original_positions = flat_input_images[:, non_zero_mask]

        # Update the output image based on the algorithm
        updated_values = torch.where(output_values_at_shifted_positions == 0,
                                    input_values_at_original_positions,
                                    (output_values_at_shifted_positions + input_values_at_original_positions) / 2)

        # Assign the updated values back to the flat output images
        flat_output_images.scatter_(1, one_d_indices.view(batch_size, -1), updated_values)

        # Reshape the flat output images back to their original shape
        output_images = flat_output_images.view(batch_size, self.profile_size, self.profile_size)


        # Normalize the output images
        max_values, _ = output_images.max(dim=1, keepdim=True)
        max_values, _ = max_values.max(dim=2, keepdim=True)
        output_images = output_images / (max_values + self.eps)

        return output_images.unsqueeze(1) # Add channel dimension back


class HEAL_Swin(nn.Module):
    """
    Swin Transformer with a Relativistic Physical Informed Encoder.
    This model first applies a physics-informed transformation to the input image
    before processing it with the Swin Transformer for classification.
    """

    def __init__(self, img_size=(150, 150), patch_size=(10, 10), in_chans=1, num_classes=3,
                 embed_dim=96, depths=[2, 2, 6], num_heads=[3, 6, 12],
                 window_size=(5, 5), mlp_ratio=4., qkv_bias=True, qk_scale=None,
                 drop_rate=0., attn_drop_rate=0., drop_path_rate=0.1,
                 norm_layer=nn.LayerNorm, ape=False, patch_norm=True,
                 # Relativistic Encoder Params
                 relativistic_encoder_params=None,
                 device=torch.device("cuda" if torch.cuda.is_available() else "cpu"),
                 **kwargs):
        super().__init__()

        self.num_classes = num_classes
        self.num_layers = len(depths)
        self.embed_dim = embed_dim
        self.ape = ape
        self.patch_norm = patch_norm
        self.num_features = int(embed_dim)
        self.mlp_ratio = mlp_ratio
        self.device = device

        # Split image into non-overlapping patches
        self.patch_embed = PatchEmbed(
            img_size=img_size, patch_size=patch_size, in_chans=in_chans, embed_dim=embed_dim,
            norm_layer=norm_layer if self.patch_norm else None)
        num_patches = self.patch_embed.num_patches
        patches_resolution = self.patch_embed.patches_resolution
        self.patches_resolution = patches_resolution

        # Relativistic Physical Informed Encoder
        if relativistic_encoder_params is None:
            relativistic_encoder_params = {
                'image_size': img_size[0],
                'patch_size': patch_size[0],
                'embed_dim': embed_dim,
                'num_patches': num_patches,
                'num_heads': num_heads[0],
                'num_hidden_neurons': int(embed_dim * mlp_ratio),
                'transformer_activation_function': nn.GELU,
                'num_transformer_blocks': 2,
                'device': self.device
            }
        self.relativistic_encoder = RelativisticPhysicalInformedEncoder(**relativistic_encoder_params)


        # Absolute position embedding
        if self.ape:
            self.absolute_pos_embed = nn.Parameter(torch.zeros(1, num_patches, embed_dim))
            trunc_normal_(self.absolute_pos_embed, std=.02)

        self.pos_drop = nn.Dropout(p=drop_rate)

        # Stochastic depth
        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, sum(depths))]

        # Build layers
        self.layers = nn.ModuleList()
        layer = BasicLayer(dim=int(embed_dim),
                           input_resolution=patches_resolution,
                           depth=sum(depths),
                           num_heads=num_heads[0],
                           window_size=window_size,
                           mlp_ratio=self.mlp_ratio,
                           qkv_bias=qkv_bias, qk_scale=qk_scale,
                           drop=drop_rate, attn_drop=attn_drop_rate,
                           drop_path=dpr,
                           norm_layer=norm_layer,
                           downsample=None)
        self.layers.append(layer)

        self.norm = norm_layer(self.num_features)
        self.avgpool = nn.AdaptiveAvgPool1d(1)
        self.head = nn.Linear(self.num_features, num_classes) if num_classes > 0 else nn.Identity()

        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            trunc_normal_(m.weight, std=.02)
            if isinstance(m, nn.Linear) and m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.LayerNorm):
            nn.init.constant_(m.bias, 0)
            nn.init.constant_(m.weight, 1.0)

    @torch.jit.ignore
    def no_weight_decay(self):
        return {'absolute_pos_embed'}

    @torch.jit.ignore
    def no_weight_decay_keywords(self):
        return {'relative_position_bias_table'}

    def forward_features(self, x):
        # First, get the patches
        patches = self.patch_embed(x)

        # Pass original image and patches to the relativistic encoder
        x_encoded = self.relativistic_encoder(x, patches)

        # Now, embed the encoded image
        x = self.patch_embed(x_encoded)

        if self.ape:
            x = x + self.absolute_pos_embed
        x = self.pos_drop(x)

        for layer in self.layers:
            x = layer(x)

        x = self.norm(x)
        x = self.avgpool(x.transpose(1, 2))
        x = torch.flatten(x, 1)
        return x

    def forward(self, x):
        x = self.forward_features(x)
        x = self.head(x)
        return x
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
#!pip install torch_xla[tpu]

# %%
#import torch_xla

# %%
import torch
import numpy as np
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
import copy
import matplotlib.pyplot as plt
from itertools import cycle

def plot_roc_curve(all_labels, all_probs, class_names):
    """
    Plots the ROC curve for each class and the micro/macro averages.
    """
    # Binarize the labels for multi-class ROC analysis
    all_labels_bin = label_binarize(all_labels, classes=range(len(class_names)))
    all_probs = np.array(all_probs)

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(len(class_names)):
        fpr[i], tpr[i], _ = roc_curve(all_labels_bin[:, i], all_probs[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(all_labels_bin.ravel(), all_probs.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # Compute macro-average ROC curve and ROC area
    # First aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(len(class_names))]))
    # Then interpolate all ROC curves at these points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(len(class_names)):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
    # Finally average it and compute AUC
    mean_tpr /= len(class_names)
    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    plt.figure(figsize=(10, 8))

    plt.plot(fpr["micro"], tpr["micro"],
             label=f'micro-average ROC curve (area = {roc_auc["micro"]:.2f})',
             color='deeppink', linestyle=':', linewidth=4)

    plt.plot(fpr["macro"], tpr["macro"],
             label=f'macro-average ROC curve (area = {roc_auc["macro"]:.2f})',
             color='navy', linestyle=':', linewidth=4)

    colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
    for i, color in zip(range(len(class_names)), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=2,
                 label=f'ROC curve of class {class_names[i]} (area = {roc_auc[i]:.2f})')

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Multi-class Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    plt.savefig("/content/drive/MyDrive/Model_III_dataset/roc_curve_heal_swin_pinn.png")
    print("\nROC curve plot saved as roc_curve.png")

"""Training and Evaluation with Early Stopping"""
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs=50, patience=2000):
    """
    Trains the model with early stopping based on validation ROC AUC score.

    Args:
        model (torch.nn.Module): The neural network model to train.
        train_loader (torch.utils.data.DataLoader): DataLoader for the training set.
        val_loader (torch.utils.data.DataLoader): DataLoader for the validation set.
        criterion: The loss function.
        optimizer: The optimization algorithm.
        scheduler: The learning rate scheduler.
        num_epochs (int): The maximum number of epochs to train for.
        patience (int): Number of epochs to wait for improvement before stopping.
    """
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Training on device: {device}")

    model.to(device)

    best_roc_auc = 0.0
    epochs_no_improve = 0
    best_model_wts = copy.deepcopy(model.state_dict())
    best_probs = []
    best_labels = []

    class_names = ['axion', 'cdm', 'no_sub']

    for epoch in range(num_epochs):
        print(f"===== Epoch {epoch+1}/{num_epochs} =====")

        # --- Training Phase ---
        model.train()
        train_loss = 0.0
        train_correct = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            scheduler.step()

            train_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs.data, 1)
            train_correct += (predicted == labels).sum().item()

        # --- Validation Phase ---
        model.eval()
        val_loss = 0.0
        val_correct = 0
        all_probs = []
        all_labels = []

        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * images.size(0)
                _, predicted = torch.max(outputs.data, 1)
                val_correct += (predicted == labels).sum().item()

                probs = torch.softmax(outputs, dim=1)
                all_probs.extend(probs.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())

        # --- Calculate Metrics ---
        train_loss = train_loss / len(train_loader.dataset)
        val_loss = val_loss / len(val_loader.dataset)
        train_accuracy = train_correct / len(train_loader.dataset)
        val_accuracy = val_correct / len(val_loader.dataset)

        # Calculate multi-class ROC AUC score
        all_labels_np = np.array(all_labels)
        all_probs_np = np.array(all_probs)
        try:
            val_roc_auc = roc_auc_score(all_labels_np, all_probs_np, multi_class='ovr', average='macro')
        except ValueError as e:
            print(f"Could not calculate ROC AUC: {e}")
            val_roc_auc = 0.0

        # Epoch-level summary
        #print(f'\n[SUMMARY] Epoch {epoch+1}/{num_epochs}:')
        #print(f'Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}')
        #print(f'Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}, Val ROC AUC: {val_roc_auc:.4f}')

        if val_roc_auc > best_roc_auc:
            best_roc_auc = val_roc_auc
            epochs_no_improve = 0
            best_model_wts = copy.deepcopy(model.state_dict())
            best_probs = all_probs
            best_labels = all_labels
            #torch.save(model.state_dict(), '/content/drive/MyDrive/Model_III_dataset/lens_classifier_model_vision_transformer.pth')
            print(f"New best model saved with Val ROC AUC: {best_roc_auc:.4f}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")
        else:
            epochs_no_improve += 1
            print(f"No improvement in Val ROC AUC for {epochs_no_improve} epoch(s). Best is {best_roc_auc:.4f}. Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")

        if epochs_no_improve >= patience:
            print(f"\nEarly stopping triggered after {patience} epochs without improvement.")
            model.load_state_dict(best_model_wts)
            break

    print("\nTraining Complete!")
    model.load_state_dict(best_model_wts)

    # After the training loop, plot the ROC curve for the best model
    if best_probs and best_labels:
        plot_roc_curve(best_labels, best_probs, class_names)

    return model, best_probs, best_labels

# %%
#torch.save(model.state_dict(), '/content/drive/MyDrive/Model_III_dataset/model_weights.pth')

# %%
"""
Args:
        image_size (int): Size of the input image (e.g., 224).
        patch_size (int): Size of each patch (e.g., 16).
        in_channels (int): Number of input channels (e.g., 1 for your task).
        num_classes (int): Number of output classes (e.g., 3 for your task).
        embed_dim (int): The main embedding dimension (e.g., 768 for ViT-Base).
        depth (int): Number of Transformer Encoder blocks (e.g., 12 for ViT-Base).
        num_heads (int): Number of attention heads (e.g., 12 for ViT-Base).
        mlp_ratio (float): Ratio to determine MLP hidden dimension (e.g., 4.0).
        dropout (float): Dropout probability.
"""
from torch.optim.lr_scheduler import LambdaLR, CosineAnnealingLR, SequentialLR
batch_size = 32
learning_rate = 1e-4
weight_decay = 0.05
num_epochs = 2000
warmup_epochs = 10
"""
model = SwinTransformerForClassification(
        img_size=(150, 150),
        patch_size=(10, 10),
        in_chans=1,
        num_classes=3,      # Same number of classes as the ViT example
        embed_dim=48,
        depths=[2, 2, 2, 2],
        num_heads=[3, 6, 12, 24],
        window_size=(5, 5),
        drop_path_rate=0.2,
    )"""
model = HEAL_Swin(img_size=(150, 150), patch_size=(10, 10), num_classes=3)


criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=0.05)


#scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs, eta_min=1e-6)
def warmup_lambda(current_epoch):
    if current_epoch < warmup_epochs:
        return float(current_epoch) / float(max(1, warmup_epochs))
    return 1.0
warmup_scheduler = LambdaLR(optimizer, lr_lambda=warmup_lambda)
main_scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs - warmup_epochs, eta_min=1e-6)
scheduler = SequentialLR(optimizer, schedulers=[warmup_scheduler, main_scheduler], milestones=[warmup_epochs])


print("Optimizer: Adam")
print(f"Learning Rate: {learning_rate}")

# Train Model
model, all_probs, all_labels = train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs)
# Out:
# Optimizer: Adam
# Learning Rate: 0.0001
# Training on device: cuda
# ===== Epoch 1/2000 =====
# /usr/local/lib/python3.12/dist-packages/torch/optim/lr_scheduler.py:209: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# New best model saved with Val ROC AUC: 0.4480, Train Loss: 1.1110, Train Accuracy: 0.3231, Val Loss: 1.1052, Val Accuracy: 0.2844
# ===== Epoch 2/2000 =====
# New best model saved with Val ROC AUC: 0.5080, Train Loss: 1.1019, Train Accuracy: 0.3153, Val Loss: 1.1001, Val Accuracy: 0.2889
# ===== Epoch 3/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.5080. Train Loss: 1.1015, Train Accuracy: 0.3216, Val Loss: 1.1146, Val Accuracy: 0.2844
# ===== Epoch 4/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.5080. Train Loss: 1.1012, Train Accuracy: 0.3388, Val Loss: 1.1083, Val Accuracy: 0.2844
# ===== Epoch 5/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.5080. Train Loss: 1.1060, Train Accuracy: 0.3263, Val Loss: 1.1103, Val Accuracy: 0.2844
# ===== Epoch 6/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.5080. Train Loss: 1.1026, Train Accuracy: 0.3082, Val Loss: 1.1007, Val Accuracy: 0.3378
# ===== Epoch 7/2000 =====
# No improvement in Val ROC AUC for 5 epoch(s). Best is 0.5080. Train Loss: 1.0995, Train Accuracy: 0.3388, Val Loss: 1.1015, Val Accuracy: 0.3378
# ===== Epoch 8/2000 =====
# New best model saved with Val ROC AUC: 0.5128, Train Loss: 1.1021, Train Accuracy: 0.3231, Val Loss: 1.1128, Val Accuracy: 0.2844
# ===== Epoch 9/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.5128. Train Loss: 1.1014, Train Accuracy: 0.3192, Val Loss: 1.0992, Val Accuracy: 0.3778
# ===== Epoch 10/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.5128. Train Loss: 1.0994, Train Accuracy: 0.3286, Val Loss: 1.0986, Val Accuracy: 0.3378
# ===== Epoch 11/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.5128. Train Loss: 1.1000, Train Accuracy: 0.3090, Val Loss: 1.0995, Val Accuracy: 0.2844
# ===== Epoch 12/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.5128. Train Loss: 1.1004, Train Accuracy: 0.3122, Val Loss: 1.1009, Val Accuracy: 0.3378
# ===== Epoch 13/2000 =====
# New best model saved with Val ROC AUC: 0.5296, Train Loss: 1.1001, Train Accuracy: 0.3224, Val Loss: 1.1005, Val Accuracy: 0.3156
# ===== Epoch 14/2000 =====
# New best model saved with Val ROC AUC: 0.5314, Train Loss: 1.1005, Train Accuracy: 0.3192, Val Loss: 1.1088, Val Accuracy: 0.2844
# ===== Epoch 15/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.5314. Train Loss: 1.0993, Train Accuracy: 0.3420, Val Loss: 1.1001, Val Accuracy: 0.2844
# ===== Epoch 16/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.5314. Train Loss: 1.1005, Train Accuracy: 0.3192, Val Loss: 1.1005, Val Accuracy: 0.3778
# ===== Epoch 17/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.5314. Train Loss: 1.1006, Train Accuracy: 0.3271, Val Loss: 1.1025, Val Accuracy: 0.3067
# ===== Epoch 18/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.5314. Train Loss: 1.1007, Train Accuracy: 0.3404, Val Loss: 1.0951, Val Accuracy: 0.3778
# ===== Epoch 19/2000 =====
# No improvement in Val ROC AUC for 5 epoch(s). Best is 0.5314. Train Loss: 1.0997, Train Accuracy: 0.3224, Val Loss: 1.1016, Val Accuracy: 0.2844
# ===== Epoch 20/2000 =====
# No improvement in Val ROC AUC for 6 epoch(s). Best is 0.5314. Train Loss: 1.1002, Train Accuracy: 0.3192, Val Loss: 1.1000, Val Accuracy: 0.2844
# ===== Epoch 21/2000 =====
# No improvement in Val ROC AUC for 7 epoch(s). Best is 0.5314. Train Loss: 1.0989, Train Accuracy: 0.3467, Val Loss: 1.0987, Val Accuracy: 0.3378
# ===== Epoch 22/2000 =====
# No improvement in Val ROC AUC for 8 epoch(s). Best is 0.5314. Train Loss: 1.0999, Train Accuracy: 0.3122, Val Loss: 1.0983, Val Accuracy: 0.3511
# ===== Epoch 23/2000 =====
# New best model saved with Val ROC AUC: 0.5349, Train Loss: 1.0990, Train Accuracy: 0.3333, Val Loss: 1.0995, Val Accuracy: 0.3378
# ===== Epoch 24/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.5349. Train Loss: 1.0988, Train Accuracy: 0.3365, Val Loss: 1.0996, Val Accuracy: 0.2978
# ===== Epoch 25/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.5349. Train Loss: 1.0988, Train Accuracy: 0.3490, Val Loss: 1.1012, Val Accuracy: 0.2844
# ===== Epoch 26/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.5349. Train Loss: 1.0991, Train Accuracy: 0.3459, Val Loss: 1.0997, Val Accuracy: 0.2844
# ===== Epoch 27/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.5349. Train Loss: 1.0991, Train Accuracy: 0.3294, Val Loss: 1.1011, Val Accuracy: 0.2844
# ===== Epoch 28/2000 =====
# New best model saved with Val ROC AUC: 0.5394, Train Loss: 1.0985, Train Accuracy: 0.3435, Val Loss: 1.0991, Val Accuracy: 0.3422
# ===== Epoch 29/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.5394. Train Loss: 1.0990, Train Accuracy: 0.3396, Val Loss: 1.1003, Val Accuracy: 0.2844
# ===== Epoch 30/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.5394. Train Loss: 1.0981, Train Accuracy: 0.3529, Val Loss: 1.0999, Val Accuracy: 0.3289
# ===== Epoch 31/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.5394. Train Loss: 1.0983, Train Accuracy: 0.3427, Val Loss: 1.1006, Val Accuracy: 0.2844
# ===== Epoch 32/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.5394. Train Loss: 1.0984, Train Accuracy: 0.3443, Val Loss: 1.1002, Val Accuracy: 0.2844
# ===== Epoch 33/2000 =====
# New best model saved with Val ROC AUC: 0.5512, Train Loss: 1.0987, Train Accuracy: 0.3404, Val Loss: 1.0992, Val Accuracy: 0.3600
# ===== Epoch 34/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.5512. Train Loss: 1.0982, Train Accuracy: 0.3545, Val Loss: 1.0996, Val Accuracy: 0.2844
# ===== Epoch 35/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.5512. Train Loss: 1.0982, Train Accuracy: 0.3420, Val Loss: 1.0992, Val Accuracy: 0.3511
# ===== Epoch 36/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.5512. Train Loss: 1.0979, Train Accuracy: 0.3647, Val Loss: 1.1000, Val Accuracy: 0.3333
# ===== Epoch 37/2000 =====
# New best model saved with Val ROC AUC: 0.5532, Train Loss: 1.0978, Train Accuracy: 0.3537, Val Loss: 1.1000, Val Accuracy: 0.2844
# ===== Epoch 38/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.5532. Train Loss: 1.0978, Train Accuracy: 0.3451, Val Loss: 1.1009, Val Accuracy: 0.2844
# ===== Epoch 39/2000 =====
# New best model saved with Val ROC AUC: 0.6003, Train Loss: 1.0976, Train Accuracy: 0.3694, Val Loss: 1.0988, Val Accuracy: 0.3111
# ===== Epoch 40/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.6003. Train Loss: 1.0977, Train Accuracy: 0.3569, Val Loss: 1.1000, Val Accuracy: 0.2844
# ===== Epoch 41/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.6003. Train Loss: 1.0978, Train Accuracy: 0.3459, Val Loss: 1.0999, Val Accuracy: 0.2844
# ===== Epoch 42/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.6003. Train Loss: 1.0974, Train Accuracy: 0.3576, Val Loss: 1.1000, Val Accuracy: 0.2933
# ===== Epoch 43/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.6003. Train Loss: 1.0976, Train Accuracy: 0.3514, Val Loss: 1.0996, Val Accuracy: 0.3022
# ===== Epoch 44/2000 =====
# No improvement in Val ROC AUC for 5 epoch(s). Best is 0.6003. Train Loss: 1.0977, Train Accuracy: 0.3576, Val Loss: 1.0996, Val Accuracy: 0.2933
# ===== Epoch 45/2000 =====
# No improvement in Val ROC AUC for 6 epoch(s). Best is 0.6003. Train Loss: 1.0974, Train Accuracy: 0.3592, Val Loss: 1.0997, Val Accuracy: 0.2889
# ===== Epoch 46/2000 =====
# No improvement in Val ROC AUC for 7 epoch(s). Best is 0.6003. Train Loss: 1.0978, Train Accuracy: 0.3514, Val Loss: 1.0994, Val Accuracy: 0.3156
# ===== Epoch 47/2000 =====
# No improvement in Val ROC AUC for 8 epoch(s). Best is 0.6003. Train Loss: 1.0977, Train Accuracy: 0.3514, Val Loss: 1.0999, Val Accuracy: 0.2844
# ===== Epoch 48/2000 =====
# No improvement in Val ROC AUC for 9 epoch(s). Best is 0.6003. Train Loss: 1.0972, Train Accuracy: 0.3655, Val Loss: 1.0998, Val Accuracy: 0.2889
# ===== Epoch 49/2000 =====
# No improvement in Val ROC AUC for 10 epoch(s). Best is 0.6003. Train Loss: 1.0975, Train Accuracy: 0.3569, Val Loss: 1.0996, Val Accuracy: 0.2978
# ===== Epoch 50/2000 =====
# No improvement in Val ROC AUC for 11 epoch(s). Best is 0.6003. Train Loss: 1.0974, Train Accuracy: 0.3616, Val Loss: 1.0995, Val Accuracy: 0.3022
# ===== Epoch 51/2000 =====
# New best model saved with Val ROC AUC: 0.6031, Train Loss: 1.0972, Train Accuracy: 0.3608, Val Loss: 1.0992, Val Accuracy: 0.3067
# ===== Epoch 52/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.6031. Train Loss: 1.0976, Train Accuracy: 0.3569, Val Loss: 1.0999, Val Accuracy: 0.2844
# ===== Epoch 53/2000 =====
# New best model saved with Val ROC AUC: 0.6076, Train Loss: 1.0974, Train Accuracy: 0.3482, Val Loss: 1.0992, Val Accuracy: 0.2889
# ===== Epoch 54/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.6076. Train Loss: 1.0975, Train Accuracy: 0.3537, Val Loss: 1.0994, Val Accuracy: 0.3111
# ===== Epoch 55/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.6076. Train Loss: 1.0975, Train Accuracy: 0.3592, Val Loss: 1.0992, Val Accuracy: 0.3244
# ===== Epoch 56/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.6076. Train Loss: 1.0975, Train Accuracy: 0.3576, Val Loss: 1.0994, Val Accuracy: 0.3289
# ===== Epoch 57/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.6076. Train Loss: 1.0978, Train Accuracy: 0.3545, Val Loss: 1.0994, Val Accuracy: 0.3067
# ===== Epoch 58/2000 =====
# No improvement in Val ROC AUC for 5 epoch(s). Best is 0.6076. Train Loss: 1.0978, Train Accuracy: 0.3647, Val Loss: 1.0993, Val Accuracy: 0.2889
# ===== Epoch 59/2000 =====
# No improvement in Val ROC AUC for 6 epoch(s). Best is 0.6076. Train Loss: 1.0972, Train Accuracy: 0.3576, Val Loss: 1.0998, Val Accuracy: 0.2844
# ===== Epoch 60/2000 =====
# No improvement in Val ROC AUC for 7 epoch(s). Best is 0.6076. Train Loss: 1.0981, Train Accuracy: 0.3451, Val Loss: 1.0994, Val Accuracy: 0.3467
# ===== Epoch 61/2000 =====
# New best model saved with Val ROC AUC: 0.6126, Train Loss: 1.0976, Train Accuracy: 0.3694, Val Loss: 1.0987, Val Accuracy: 0.3556
# ===== Epoch 62/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.6126. Train Loss: 1.0977, Train Accuracy: 0.3482, Val Loss: 1.0990, Val Accuracy: 0.3156
# ===== Epoch 63/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.6126. Train Loss: 1.0974, Train Accuracy: 0.3537, Val Loss: 1.0989, Val Accuracy: 0.2889
# ===== Epoch 64/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.6126. Train Loss: 1.0978, Train Accuracy: 0.3451, Val Loss: 1.0990, Val Accuracy: 0.2889
# ===== Epoch 65/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.6126. Train Loss: 1.0977, Train Accuracy: 0.3522, Val Loss: 1.0980, Val Accuracy: 0.3289
# ===== Epoch 66/2000 =====
# No improvement in Val ROC AUC for 5 epoch(s). Best is 0.6126. Train Loss: 1.0974, Train Accuracy: 0.3725, Val Loss: 1.0994, Val Accuracy: 0.2978
# ===== Epoch 67/2000 =====
# New best model saved with Val ROC AUC: 0.6250, Train Loss: 1.0974, Train Accuracy: 0.3718, Val Loss: 1.0993, Val Accuracy: 0.2844
# ===== Epoch 68/2000 =====
# New best model saved with Val ROC AUC: 0.6466, Train Loss: 1.0975, Train Accuracy: 0.3678, Val Loss: 1.0997, Val Accuracy: 0.2933
# ===== Epoch 69/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.6466. Train Loss: 1.0978, Train Accuracy: 0.3537, Val Loss: 1.0987, Val Accuracy: 0.3022
# ===== Epoch 70/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.6466. Train Loss: 1.0980, Train Accuracy: 0.3451, Val Loss: 1.0989, Val Accuracy: 0.3778
# ===== Epoch 71/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.6466. Train Loss: 1.0973, Train Accuracy: 0.3851, Val Loss: 1.0938, Val Accuracy: 0.4000
# ===== Epoch 72/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.6466. Train Loss: 1.0964, Train Accuracy: 0.3553, Val Loss: 1.0940, Val Accuracy: 0.3289
# ===== Epoch 73/2000 =====
# No improvement in Val ROC AUC for 5 epoch(s). Best is 0.6466. Train Loss: 1.0971, Train Accuracy: 0.3529, Val Loss: 1.0971, Val Accuracy: 0.3511
# ===== Epoch 74/2000 =====
# No improvement in Val ROC AUC for 6 epoch(s). Best is 0.6466. Train Loss: 1.0958, Train Accuracy: 0.3529, Val Loss: 1.0992, Val Accuracy: 0.2844
# ===== Epoch 75/2000 =====
# No improvement in Val ROC AUC for 7 epoch(s). Best is 0.6466. Train Loss: 1.0957, Train Accuracy: 0.3631, Val Loss: 1.0936, Val Accuracy: 0.3867
# ===== Epoch 76/2000 =====
# No improvement in Val ROC AUC for 8 epoch(s). Best is 0.6466. Train Loss: 1.0976, Train Accuracy: 0.3631, Val Loss: 1.0964, Val Accuracy: 0.3378
# ===== Epoch 77/2000 =====
# No improvement in Val ROC AUC for 9 epoch(s). Best is 0.6466. Train Loss: 1.0945, Train Accuracy: 0.3616, Val Loss: 1.1004, Val Accuracy: 0.2933
# ===== Epoch 78/2000 =====
# No improvement in Val ROC AUC for 10 epoch(s). Best is 0.6466. Train Loss: 1.0944, Train Accuracy: 0.3710, Val Loss: 1.0907, Val Accuracy: 0.4222
# ===== Epoch 79/2000 =====
# No improvement in Val ROC AUC for 11 epoch(s). Best is 0.6466. Train Loss: 1.0951, Train Accuracy: 0.3537, Val Loss: 1.0919, Val Accuracy: 0.4178
# ===== Epoch 80/2000 =====
# No improvement in Val ROC AUC for 12 epoch(s). Best is 0.6466. Train Loss: 1.0939, Train Accuracy: 0.3671, Val Loss: 1.0944, Val Accuracy: 0.3467
# ===== Epoch 81/2000 =====
# No improvement in Val ROC AUC for 13 epoch(s). Best is 0.6466. Train Loss: 1.0934, Train Accuracy: 0.3820, Val Loss: 1.0952, Val Accuracy: 0.3600
# ===== Epoch 82/2000 =====
# No improvement in Val ROC AUC for 14 epoch(s). Best is 0.6466. Train Loss: 1.0891, Train Accuracy: 0.4055, Val Loss: 1.0961, Val Accuracy: 0.3644
# ===== Epoch 83/2000 =====
# No improvement in Val ROC AUC for 15 epoch(s). Best is 0.6466. Train Loss: 1.0932, Train Accuracy: 0.3671, Val Loss: 1.0956, Val Accuracy: 0.3511
# ===== Epoch 84/2000 =====
# No improvement in Val ROC AUC for 16 epoch(s). Best is 0.6466. Train Loss: 1.0931, Train Accuracy: 0.3749, Val Loss: 1.1019, Val Accuracy: 0.3200
# ===== Epoch 85/2000 =====
# No improvement in Val ROC AUC for 17 epoch(s). Best is 0.6466. Train Loss: 1.0951, Train Accuracy: 0.3694, Val Loss: 1.0978, Val Accuracy: 0.3422
# ===== Epoch 86/2000 =====
# No improvement in Val ROC AUC for 18 epoch(s). Best is 0.6466. Train Loss: 1.0949, Train Accuracy: 0.3639, Val Loss: 1.0898, Val Accuracy: 0.4000
# ===== Epoch 87/2000 =====
# No improvement in Val ROC AUC for 19 epoch(s). Best is 0.6466. Train Loss: 1.0882, Train Accuracy: 0.4047, Val Loss: 1.0791, Val Accuracy: 0.4222
# ===== Epoch 88/2000 =====
# No improvement in Val ROC AUC for 20 epoch(s). Best is 0.6466. Train Loss: 1.0899, Train Accuracy: 0.3678, Val Loss: 1.1059, Val Accuracy: 0.3333
# ===== Epoch 89/2000 =====
# No improvement in Val ROC AUC for 21 epoch(s). Best is 0.6466. Train Loss: 1.0909, Train Accuracy: 0.3945, Val Loss: 1.0918, Val Accuracy: 0.3822
# ===== Epoch 90/2000 =====
# No improvement in Val ROC AUC for 22 epoch(s). Best is 0.6466. Train Loss: 1.0909, Train Accuracy: 0.3741, Val Loss: 1.0903, Val Accuracy: 0.3956
# ===== Epoch 91/2000 =====
# No improvement in Val ROC AUC for 23 epoch(s). Best is 0.6466. Train Loss: 1.0925, Train Accuracy: 0.3584, Val Loss: 1.0885, Val Accuracy: 0.3911
# ===== Epoch 92/2000 =====
# No improvement in Val ROC AUC for 24 epoch(s). Best is 0.6466. Train Loss: 1.0891, Train Accuracy: 0.3890, Val Loss: 1.0795, Val Accuracy: 0.3733
# ===== Epoch 93/2000 =====
# No improvement in Val ROC AUC for 25 epoch(s). Best is 0.6466. Train Loss: 1.0952, Train Accuracy: 0.3647, Val Loss: 1.0844, Val Accuracy: 0.4222
# ===== Epoch 94/2000 =====
# No improvement in Val ROC AUC for 26 epoch(s). Best is 0.6466. Train Loss: 1.0913, Train Accuracy: 0.3804, Val Loss: 1.0832, Val Accuracy: 0.4000
# ===== Epoch 95/2000 =====
# No improvement in Val ROC AUC for 27 epoch(s). Best is 0.6466. Train Loss: 1.0895, Train Accuracy: 0.3875, Val Loss: 1.0771, Val Accuracy: 0.4222
# ===== Epoch 96/2000 =====
# No improvement in Val ROC AUC for 28 epoch(s). Best is 0.6466. Train Loss: 1.0884, Train Accuracy: 0.3976, Val Loss: 1.0889, Val Accuracy: 0.3911
# ===== Epoch 97/2000 =====
# No improvement in Val ROC AUC for 29 epoch(s). Best is 0.6466. Train Loss: 1.0891, Train Accuracy: 0.3867, Val Loss: 1.0972, Val Accuracy: 0.3289
# ===== Epoch 98/2000 =====
# No improvement in Val ROC AUC for 30 epoch(s). Best is 0.6466. Train Loss: 1.0908, Train Accuracy: 0.3914, Val Loss: 1.0854, Val Accuracy: 0.4044
# ===== Epoch 99/2000 =====
# No improvement in Val ROC AUC for 31 epoch(s). Best is 0.6466. Train Loss: 1.0878, Train Accuracy: 0.3757, Val Loss: 1.0938, Val Accuracy: 0.3600
# ===== Epoch 100/2000 =====
# No improvement in Val ROC AUC for 32 epoch(s). Best is 0.6466. Train Loss: 1.0882, Train Accuracy: 0.3961, Val Loss: 1.0838, Val Accuracy: 0.3911
# ===== Epoch 101/2000 =====
# No improvement in Val ROC AUC for 33 epoch(s). Best is 0.6466. Train Loss: 1.0862, Train Accuracy: 0.4055, Val Loss: 1.0810, Val Accuracy: 0.3911
# ===== Epoch 102/2000 =====
# No improvement in Val ROC AUC for 34 epoch(s). Best is 0.6466. Train Loss: 1.0868, Train Accuracy: 0.3992, Val Loss: 1.0746, Val Accuracy: 0.4267
# ===== Epoch 103/2000 =====
# No improvement in Val ROC AUC for 35 epoch(s). Best is 0.6466. Train Loss: 1.0889, Train Accuracy: 0.3710, Val Loss: 1.0797, Val Accuracy: 0.3778
# ===== Epoch 104/2000 =====
# No improvement in Val ROC AUC for 36 epoch(s). Best is 0.6466. Train Loss: 1.0837, Train Accuracy: 0.4094, Val Loss: 1.0897, Val Accuracy: 0.3556
# ===== Epoch 105/2000 =====
# No improvement in Val ROC AUC for 37 epoch(s). Best is 0.6466. Train Loss: 1.0848, Train Accuracy: 0.3929, Val Loss: 1.0776, Val Accuracy: 0.4489
# ===== Epoch 106/2000 =====
# No improvement in Val ROC AUC for 38 epoch(s). Best is 0.6466. Train Loss: 1.0853, Train Accuracy: 0.3922, Val Loss: 1.0877, Val Accuracy: 0.3689
# ===== Epoch 107/2000 =====
# No improvement in Val ROC AUC for 39 epoch(s). Best is 0.6466. Train Loss: 1.0805, Train Accuracy: 0.4086, Val Loss: 1.0725, Val Accuracy: 0.4044
# ===== Epoch 108/2000 =====
# No improvement in Val ROC AUC for 40 epoch(s). Best is 0.6466. Train Loss: 1.0832, Train Accuracy: 0.4000, Val Loss: 1.0749, Val Accuracy: 0.3867
# ===== Epoch 109/2000 =====
# No improvement in Val ROC AUC for 41 epoch(s). Best is 0.6466. Train Loss: 1.0806, Train Accuracy: 0.4133, Val Loss: 1.1139, Val Accuracy: 0.3156
# ===== Epoch 110/2000 =====
# No improvement in Val ROC AUC for 42 epoch(s). Best is 0.6466. Train Loss: 1.0845, Train Accuracy: 0.3914, Val Loss: 1.0926, Val Accuracy: 0.3378
# ===== Epoch 111/2000 =====
# No improvement in Val ROC AUC for 43 epoch(s). Best is 0.6466. Train Loss: 1.0902, Train Accuracy: 0.3922, Val Loss: 1.0717, Val Accuracy: 0.4311
# ===== Epoch 112/2000 =====
# New best model saved with Val ROC AUC: 0.6521, Train Loss: 1.0834, Train Accuracy: 0.3780, Val Loss: 1.0817, Val Accuracy: 0.3733
# ===== Epoch 113/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.6521. Train Loss: 1.0805, Train Accuracy: 0.4008, Val Loss: 1.0919, Val Accuracy: 0.3644
# ===== Epoch 114/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.6521. Train Loss: 1.0789, Train Accuracy: 0.4024, Val Loss: 1.0773, Val Accuracy: 0.3911
# ===== Epoch 115/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.6521. Train Loss: 1.0718, Train Accuracy: 0.4118, Val Loss: 1.0702, Val Accuracy: 0.3822
# ===== Epoch 116/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.6521. Train Loss: 1.0762, Train Accuracy: 0.4110, Val Loss: 1.0797, Val Accuracy: 0.3822
# ===== Epoch 117/2000 =====
# No improvement in Val ROC AUC for 5 epoch(s). Best is 0.6521. Train Loss: 1.0697, Train Accuracy: 0.4188, Val Loss: 1.0641, Val Accuracy: 0.3911
# ===== Epoch 118/2000 =====
# No improvement in Val ROC AUC for 6 epoch(s). Best is 0.6521. Train Loss: 1.0751, Train Accuracy: 0.4196, Val Loss: 1.0644, Val Accuracy: 0.4444
# ===== Epoch 119/2000 =====
# New best model saved with Val ROC AUC: 0.6730, Train Loss: 1.0731, Train Accuracy: 0.4078, Val Loss: 1.0478, Val Accuracy: 0.4400
# ===== Epoch 120/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.6730. Train Loss: 1.0721, Train Accuracy: 0.4086, Val Loss: 1.0576, Val Accuracy: 0.4222
# ===== Epoch 121/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.6730. Train Loss: 1.0707, Train Accuracy: 0.4031, Val Loss: 1.0656, Val Accuracy: 0.4222
# ===== Epoch 122/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.6730. Train Loss: 1.0709, Train Accuracy: 0.4282, Val Loss: 1.0590, Val Accuracy: 0.4000
# ===== Epoch 123/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.6730. Train Loss: 1.0760, Train Accuracy: 0.4071, Val Loss: 1.0509, Val Accuracy: 0.4444
# ===== Epoch 124/2000 =====
# No improvement in Val ROC AUC for 5 epoch(s). Best is 0.6730. Train Loss: 1.0703, Train Accuracy: 0.4243, Val Loss: 1.0732, Val Accuracy: 0.3689
# ===== Epoch 125/2000 =====
# No improvement in Val ROC AUC for 6 epoch(s). Best is 0.6730. Train Loss: 1.0665, Train Accuracy: 0.4102, Val Loss: 1.0619, Val Accuracy: 0.4044
# ===== Epoch 126/2000 =====
# No improvement in Val ROC AUC for 7 epoch(s). Best is 0.6730. Train Loss: 1.0619, Train Accuracy: 0.4267, Val Loss: 1.0668, Val Accuracy: 0.3778
# ===== Epoch 127/2000 =====
# No improvement in Val ROC AUC for 8 epoch(s). Best is 0.6730. Train Loss: 1.0645, Train Accuracy: 0.4314, Val Loss: 1.0514, Val Accuracy: 0.4133
# ===== Epoch 128/2000 =====
# No improvement in Val ROC AUC for 9 epoch(s). Best is 0.6730. Train Loss: 1.0640, Train Accuracy: 0.4259, Val Loss: 1.0689, Val Accuracy: 0.4000
# ===== Epoch 129/2000 =====
# No improvement in Val ROC AUC for 10 epoch(s). Best is 0.6730. Train Loss: 1.0575, Train Accuracy: 0.4424, Val Loss: 1.0539, Val Accuracy: 0.4444
# ===== Epoch 130/2000 =====
# No improvement in Val ROC AUC for 11 epoch(s). Best is 0.6730. Train Loss: 1.0532, Train Accuracy: 0.4369, Val Loss: 1.0512, Val Accuracy: 0.4044
# ===== Epoch 131/2000 =====
# No improvement in Val ROC AUC for 12 epoch(s). Best is 0.6730. Train Loss: 1.0567, Train Accuracy: 0.4408, Val Loss: 1.0566, Val Accuracy: 0.4044
# ===== Epoch 132/2000 =====
# New best model saved with Val ROC AUC: 0.6934, Train Loss: 1.0529, Train Accuracy: 0.4345, Val Loss: 1.0287, Val Accuracy: 0.4667
# ===== Epoch 133/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.6934. Train Loss: 1.0482, Train Accuracy: 0.4573, Val Loss: 1.0458, Val Accuracy: 0.4444
# ===== Epoch 134/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.6934. Train Loss: 1.0545, Train Accuracy: 0.4416, Val Loss: 1.0434, Val Accuracy: 0.4044
# ===== Epoch 135/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.6934. Train Loss: 1.0513, Train Accuracy: 0.4329, Val Loss: 1.0287, Val Accuracy: 0.4444
# ===== Epoch 136/2000 =====
# New best model saved with Val ROC AUC: 0.7039, Train Loss: 1.0413, Train Accuracy: 0.4384, Val Loss: 1.0284, Val Accuracy: 0.4622
# ===== Epoch 137/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.7039. Train Loss: 1.0388, Train Accuracy: 0.4690, Val Loss: 1.0298, Val Accuracy: 0.4711
# ===== Epoch 138/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.7039. Train Loss: 1.0428, Train Accuracy: 0.4549, Val Loss: 1.0508, Val Accuracy: 0.4044
# ===== Epoch 139/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.7039. Train Loss: 1.0540, Train Accuracy: 0.4416, Val Loss: 1.0296, Val Accuracy: 0.4400
# ===== Epoch 140/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.7039. Train Loss: 1.0482, Train Accuracy: 0.4580, Val Loss: 1.0192, Val Accuracy: 0.4533
# ===== Epoch 141/2000 =====
# No improvement in Val ROC AUC for 5 epoch(s). Best is 0.7039. Train Loss: 1.0446, Train Accuracy: 0.4596, Val Loss: 1.0311, Val Accuracy: 0.4400
# ===== Epoch 142/2000 =====
# No improvement in Val ROC AUC for 6 epoch(s). Best is 0.7039. Train Loss: 1.0506, Train Accuracy: 0.4416, Val Loss: 1.0326, Val Accuracy: 0.4311
# ===== Epoch 143/2000 =====
# No improvement in Val ROC AUC for 7 epoch(s). Best is 0.7039. Train Loss: 1.0424, Train Accuracy: 0.4573, Val Loss: 1.0370, Val Accuracy: 0.4400
# ===== Epoch 144/2000 =====
# No improvement in Val ROC AUC for 8 epoch(s). Best is 0.7039. Train Loss: 1.0421, Train Accuracy: 0.4541, Val Loss: 1.0166, Val Accuracy: 0.4756
# ===== Epoch 145/2000 =====
# No improvement in Val ROC AUC for 9 epoch(s). Best is 0.7039. Train Loss: 1.0429, Train Accuracy: 0.4455, Val Loss: 1.0109, Val Accuracy: 0.4444
# ===== Epoch 146/2000 =====
# No improvement in Val ROC AUC for 10 epoch(s). Best is 0.7039. Train Loss: 1.0415, Train Accuracy: 0.4486, Val Loss: 1.0407, Val Accuracy: 0.3956
# ===== Epoch 147/2000 =====
# No improvement in Val ROC AUC for 11 epoch(s). Best is 0.7039. Train Loss: 1.0441, Train Accuracy: 0.4502, Val Loss: 1.0326, Val Accuracy: 0.4444
# ===== Epoch 148/2000 =====
# No improvement in Val ROC AUC for 12 epoch(s). Best is 0.7039. Train Loss: 1.0477, Train Accuracy: 0.4518, Val Loss: 1.0291, Val Accuracy: 0.4444
# ===== Epoch 149/2000 =====
# No improvement in Val ROC AUC for 13 epoch(s). Best is 0.7039. Train Loss: 1.0439, Train Accuracy: 0.4439, Val Loss: 1.0346, Val Accuracy: 0.4311
# ===== Epoch 150/2000 =====
# No improvement in Val ROC AUC for 14 epoch(s). Best is 0.7039. Train Loss: 1.0333, Train Accuracy: 0.4651, Val Loss: 1.0236, Val Accuracy: 0.4756
# ===== Epoch 151/2000 =====
# No improvement in Val ROC AUC for 15 epoch(s). Best is 0.7039. Train Loss: 1.0381, Train Accuracy: 0.4494, Val Loss: 1.0309, Val Accuracy: 0.4489
# ===== Epoch 152/2000 =====
# No improvement in Val ROC AUC for 16 epoch(s). Best is 0.7039. Train Loss: 1.0398, Train Accuracy: 0.4541, Val Loss: 1.0325, Val Accuracy: 0.4489
# ===== Epoch 153/2000 =====
# No improvement in Val ROC AUC for 17 epoch(s). Best is 0.7039. Train Loss: 1.0361, Train Accuracy: 0.4620, Val Loss: 1.0258, Val Accuracy: 0.4267
# ===== Epoch 154/2000 =====
# No improvement in Val ROC AUC for 18 epoch(s). Best is 0.7039. Train Loss: 1.0386, Train Accuracy: 0.4643, Val Loss: 1.0251, Val Accuracy: 0.4533
# ===== Epoch 155/2000 =====
# No improvement in Val ROC AUC for 19 epoch(s). Best is 0.7039. Train Loss: 1.0414, Train Accuracy: 0.4424, Val Loss: 1.0279, Val Accuracy: 0.4578
# ===== Epoch 156/2000 =====
# No improvement in Val ROC AUC for 20 epoch(s). Best is 0.7039. Train Loss: 1.0408, Train Accuracy: 0.4525, Val Loss: 1.0217, Val Accuracy: 0.4756
# ===== Epoch 157/2000 =====
# No improvement in Val ROC AUC for 21 epoch(s). Best is 0.7039. Train Loss: 1.0408, Train Accuracy: 0.4541, Val Loss: 1.0255, Val Accuracy: 0.4533
# ===== Epoch 158/2000 =====
# No improvement in Val ROC AUC for 22 epoch(s). Best is 0.7039. Train Loss: 1.0289, Train Accuracy: 0.4667, Val Loss: 1.0362, Val Accuracy: 0.4356
# ===== Epoch 159/2000 =====
# No improvement in Val ROC AUC for 23 epoch(s). Best is 0.7039. Train Loss: 1.0480, Train Accuracy: 0.4439, Val Loss: 1.0278, Val Accuracy: 0.4044
# ===== Epoch 160/2000 =====
# No improvement in Val ROC AUC for 24 epoch(s). Best is 0.7039. Train Loss: 1.0445, Train Accuracy: 0.4573, Val Loss: 1.0167, Val Accuracy: 0.4489
# ===== Epoch 161/2000 =====
# No improvement in Val ROC AUC for 25 epoch(s). Best is 0.7039. Train Loss: 1.0352, Train Accuracy: 0.4682, Val Loss: 1.0283, Val Accuracy: 0.4489
# ===== Epoch 162/2000 =====
# No improvement in Val ROC AUC for 26 epoch(s). Best is 0.7039. Train Loss: 1.0431, Train Accuracy: 0.4392, Val Loss: 1.0350, Val Accuracy: 0.4533
# ===== Epoch 163/2000 =====
# No improvement in Val ROC AUC for 27 epoch(s). Best is 0.7039. Train Loss: 1.0382, Train Accuracy: 0.4643, Val Loss: 1.0352, Val Accuracy: 0.4222
# ===== Epoch 164/2000 =====
# No improvement in Val ROC AUC for 28 epoch(s). Best is 0.7039. Train Loss: 1.0244, Train Accuracy: 0.4651, Val Loss: 1.0190, Val Accuracy: 0.4711
# ===== Epoch 165/2000 =====
# No improvement in Val ROC AUC for 29 epoch(s). Best is 0.7039. Train Loss: 1.0277, Train Accuracy: 0.4565, Val Loss: 1.0030, Val Accuracy: 0.4533
# ===== Epoch 166/2000 =====
# New best model saved with Val ROC AUC: 0.7079, Train Loss: 1.0343, Train Accuracy: 0.4541, Val Loss: 1.0000, Val Accuracy: 0.4756
# ===== Epoch 167/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.7079. Train Loss: 1.0324, Train Accuracy: 0.4690, Val Loss: 1.0279, Val Accuracy: 0.4311
# ===== Epoch 168/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.7079. Train Loss: 1.0388, Train Accuracy: 0.4573, Val Loss: 1.0120, Val Accuracy: 0.4533
# ===== Epoch 169/2000 =====
# New best model saved with Val ROC AUC: 0.7164, Train Loss: 1.0393, Train Accuracy: 0.4384, Val Loss: 1.0192, Val Accuracy: 0.4622
# ===== Epoch 170/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.7164. Train Loss: 1.0344, Train Accuracy: 0.4580, Val Loss: 1.0134, Val Accuracy: 0.4533
# ===== Epoch 171/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.7164. Train Loss: 1.0293, Train Accuracy: 0.4627, Val Loss: 0.9921, Val Accuracy: 0.4800
# ===== Epoch 172/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.7164. Train Loss: 1.0337, Train Accuracy: 0.4533, Val Loss: 1.0039, Val Accuracy: 0.4756
# ===== Epoch 173/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.7164. Train Loss: 1.0370, Train Accuracy: 0.4463, Val Loss: 1.0069, Val Accuracy: 0.4933
# ===== Epoch 174/2000 =====
# No improvement in Val ROC AUC for 5 epoch(s). Best is 0.7164. Train Loss: 1.0279, Train Accuracy: 0.4620, Val Loss: 1.0071, Val Accuracy: 0.4711
# ===== Epoch 175/2000 =====
# No improvement in Val ROC AUC for 6 epoch(s). Best is 0.7164. Train Loss: 1.0198, Train Accuracy: 0.4745, Val Loss: 1.0191, Val Accuracy: 0.4444
# ===== Epoch 176/2000 =====
# No improvement in Val ROC AUC for 7 epoch(s). Best is 0.7164. Train Loss: 1.0324, Train Accuracy: 0.4620, Val Loss: 1.0115, Val Accuracy: 0.4756
# ===== Epoch 177/2000 =====
# No improvement in Val ROC AUC for 8 epoch(s). Best is 0.7164. Train Loss: 1.0124, Train Accuracy: 0.4753, Val Loss: 1.0197, Val Accuracy: 0.4622
# ===== Epoch 178/2000 =====
# No improvement in Val ROC AUC for 9 epoch(s). Best is 0.7164. Train Loss: 1.0102, Train Accuracy: 0.4753, Val Loss: 1.0124, Val Accuracy: 0.4311
# ===== Epoch 179/2000 =====
# No improvement in Val ROC AUC for 10 epoch(s). Best is 0.7164. Train Loss: 1.0397, Train Accuracy: 0.4486, Val Loss: 1.0062, Val Accuracy: 0.4800
# ===== Epoch 180/2000 =====
# No improvement in Val ROC AUC for 11 epoch(s). Best is 0.7164. Train Loss: 1.0267, Train Accuracy: 0.4659, Val Loss: 1.0068, Val Accuracy: 0.4400
# ===== Epoch 181/2000 =====
# New best model saved with Val ROC AUC: 0.7289, Train Loss: 1.0336, Train Accuracy: 0.4549, Val Loss: 0.9806, Val Accuracy: 0.5067
# ===== Epoch 182/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.7289. Train Loss: 1.0295, Train Accuracy: 0.4667, Val Loss: 0.9885, Val Accuracy: 0.4933
# ===== Epoch 183/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.7289. Train Loss: 1.0361, Train Accuracy: 0.4675, Val Loss: 1.0045, Val Accuracy: 0.4844
# ===== Epoch 184/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.7289. Train Loss: 1.0387, Train Accuracy: 0.4392, Val Loss: 1.0080, Val Accuracy: 0.4578
# ===== Epoch 185/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.7289. Train Loss: 1.0259, Train Accuracy: 0.4729, Val Loss: 0.9851, Val Accuracy: 0.4756
# ===== Epoch 186/2000 =====
# New best model saved with Val ROC AUC: 0.7407, Train Loss: 1.0291, Train Accuracy: 0.4533, Val Loss: 1.0793, Val Accuracy: 0.3778
# ===== Epoch 187/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.7407. Train Loss: 1.0520, Train Accuracy: 0.4337, Val Loss: 1.0258, Val Accuracy: 0.4756
# ===== Epoch 188/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.7407. Train Loss: 1.0305, Train Accuracy: 0.4596, Val Loss: 1.0102, Val Accuracy: 0.4622
# ===== Epoch 189/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.7407. Train Loss: 1.0246, Train Accuracy: 0.4525, Val Loss: 0.9751, Val Accuracy: 0.4844
# ===== Epoch 190/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.7407. Train Loss: 1.0158, Train Accuracy: 0.4839, Val Loss: 0.9976, Val Accuracy: 0.4800
# ===== Epoch 191/2000 =====
# No improvement in Val ROC AUC for 5 epoch(s). Best is 0.7407. Train Loss: 1.0222, Train Accuracy: 0.4682, Val Loss: 0.9712, Val Accuracy: 0.5067
# ===== Epoch 192/2000 =====
# No improvement in Val ROC AUC for 6 epoch(s). Best is 0.7407. Train Loss: 1.0200, Train Accuracy: 0.4667, Val Loss: 0.9812, Val Accuracy: 0.4978
# ===== Epoch 193/2000 =====
# No improvement in Val ROC AUC for 7 epoch(s). Best is 0.7407. Train Loss: 1.0221, Train Accuracy: 0.4784, Val Loss: 0.9914, Val Accuracy: 0.4756
# ===== Epoch 194/2000 =====
# No improvement in Val ROC AUC for 8 epoch(s). Best is 0.7407. Train Loss: 1.0083, Train Accuracy: 0.4737, Val Loss: 1.0404, Val Accuracy: 0.4311
# ===== Epoch 195/2000 =====
# No improvement in Val ROC AUC for 9 epoch(s). Best is 0.7407. Train Loss: 1.0071, Train Accuracy: 0.4831, Val Loss: 0.9674, Val Accuracy: 0.4889
# ===== Epoch 196/2000 =====
# No improvement in Val ROC AUC for 10 epoch(s). Best is 0.7407. Train Loss: 1.0504, Train Accuracy: 0.4416, Val Loss: 1.0312, Val Accuracy: 0.4889
# ===== Epoch 197/2000 =====
# No improvement in Val ROC AUC for 11 epoch(s). Best is 0.7407. Train Loss: 1.0236, Train Accuracy: 0.4675, Val Loss: 0.9933, Val Accuracy: 0.5022
# ===== Epoch 198/2000 =====
# No improvement in Val ROC AUC for 12 epoch(s). Best is 0.7407. Train Loss: 1.0171, Train Accuracy: 0.4714, Val Loss: 0.9826, Val Accuracy: 0.4800
# ===== Epoch 199/2000 =====
# No improvement in Val ROC AUC for 13 epoch(s). Best is 0.7407. Train Loss: 1.0140, Train Accuracy: 0.4776, Val Loss: 0.9961, Val Accuracy: 0.4578
# ===== Epoch 200/2000 =====
# No improvement in Val ROC AUC for 14 epoch(s). Best is 0.7407. Train Loss: 1.0144, Train Accuracy: 0.4776, Val Loss: 0.9838, Val Accuracy: 0.5022
# ===== Epoch 201/2000 =====
# No improvement in Val ROC AUC for 15 epoch(s). Best is 0.7407. Train Loss: 1.0044, Train Accuracy: 0.4816, Val Loss: 0.9600, Val Accuracy: 0.5511
# ===== Epoch 202/2000 =====
# New best model saved with Val ROC AUC: 0.7412, Train Loss: 0.9981, Train Accuracy: 0.4675, Val Loss: 0.9573, Val Accuracy: 0.4844
# ===== Epoch 203/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.7412. Train Loss: 0.9892, Train Accuracy: 0.4847, Val Loss: 0.9802, Val Accuracy: 0.4756
# ===== Epoch 204/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.7412. Train Loss: 0.9940, Train Accuracy: 0.4965, Val Loss: 0.9932, Val Accuracy: 0.5111
# ===== Epoch 205/2000 =====
# New best model saved with Val ROC AUC: 0.7630, Train Loss: 0.9836, Train Accuracy: 0.4980, Val Loss: 0.9301, Val Accuracy: 0.5422
# ===== Epoch 206/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.7630. Train Loss: 0.9817, Train Accuracy: 0.4973, Val Loss: 0.9325, Val Accuracy: 0.5067
# ===== Epoch 207/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.7630. Train Loss: 0.9978, Train Accuracy: 0.4753, Val Loss: 0.9417, Val Accuracy: 0.5333
# ===== Epoch 208/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.7630. Train Loss: 0.9994, Train Accuracy: 0.4808, Val Loss: 1.0682, Val Accuracy: 0.4533
# ===== Epoch 209/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.7630. Train Loss: 0.9986, Train Accuracy: 0.5059, Val Loss: 0.9699, Val Accuracy: 0.4978
# ===== Epoch 210/2000 =====
# New best model saved with Val ROC AUC: 0.7638, Train Loss: 0.9985, Train Accuracy: 0.4800, Val Loss: 0.9336, Val Accuracy: 0.5600
# ===== Epoch 211/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.7638. Train Loss: 0.9877, Train Accuracy: 0.5020, Val Loss: 0.9398, Val Accuracy: 0.5289
# ===== Epoch 212/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.7638. Train Loss: 0.9559, Train Accuracy: 0.5294, Val Loss: 0.9426, Val Accuracy: 0.5333
# ===== Epoch 213/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.7638. Train Loss: 0.9656, Train Accuracy: 0.5176, Val Loss: 0.9516, Val Accuracy: 0.5156
# ===== Epoch 214/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.7638. Train Loss: 0.9738, Train Accuracy: 0.5145, Val Loss: 0.9289, Val Accuracy: 0.5378
# ===== Epoch 215/2000 =====
# New best model saved with Val ROC AUC: 0.7646, Train Loss: 0.9413, Train Accuracy: 0.5333, Val Loss: 0.9023, Val Accuracy: 0.5289
# ===== Epoch 216/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.7646. Train Loss: 0.9422, Train Accuracy: 0.5302, Val Loss: 0.9309, Val Accuracy: 0.5378
# ===== Epoch 217/2000 =====
# New best model saved with Val ROC AUC: 0.7830, Train Loss: 0.9524, Train Accuracy: 0.5082, Val Loss: 0.8662, Val Accuracy: 0.5956
# ===== Epoch 218/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.7830. Train Loss: 0.9331, Train Accuracy: 0.5341, Val Loss: 0.9396, Val Accuracy: 0.5022
# ===== Epoch 219/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.7830. Train Loss: 0.9415, Train Accuracy: 0.5404, Val Loss: 0.8830, Val Accuracy: 0.5200
# ===== Epoch 220/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.7830. Train Loss: 0.9474, Train Accuracy: 0.5373, Val Loss: 0.9092, Val Accuracy: 0.5556
# ===== Epoch 221/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.7830. Train Loss: 0.9256, Train Accuracy: 0.5294, Val Loss: 0.8990, Val Accuracy: 0.5644
# ===== Epoch 222/2000 =====
# No improvement in Val ROC AUC for 5 epoch(s). Best is 0.7830. Train Loss: 0.9481, Train Accuracy: 0.5365, Val Loss: 0.8885, Val Accuracy: 0.5556
# ===== Epoch 223/2000 =====
# New best model saved with Val ROC AUC: 0.7968, Train Loss: 0.9099, Train Accuracy: 0.5482, Val Loss: 0.8561, Val Accuracy: 0.5778
# ===== Epoch 224/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.7968. Train Loss: 0.9305, Train Accuracy: 0.5153, Val Loss: 0.8702, Val Accuracy: 0.5511
# ===== Epoch 225/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.7968. Train Loss: 0.9290, Train Accuracy: 0.5522, Val Loss: 0.8933, Val Accuracy: 0.6044
# ===== Epoch 226/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.7968. Train Loss: 0.9473, Train Accuracy: 0.5333, Val Loss: 0.9167, Val Accuracy: 0.5244
# ===== Epoch 227/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.7968. Train Loss: 0.9193, Train Accuracy: 0.5537, Val Loss: 0.8945, Val Accuracy: 0.5511
# ===== Epoch 228/2000 =====
# No improvement in Val ROC AUC for 5 epoch(s). Best is 0.7968. Train Loss: 0.9131, Train Accuracy: 0.5373, Val Loss: 0.8826, Val Accuracy: 0.5778
# ===== Epoch 229/2000 =====
# No improvement in Val ROC AUC for 6 epoch(s). Best is 0.7968. Train Loss: 0.9029, Train Accuracy: 0.5631, Val Loss: 0.9389, Val Accuracy: 0.5333
# ===== Epoch 230/2000 =====
# No improvement in Val ROC AUC for 7 epoch(s). Best is 0.7968. Train Loss: 0.9012, Train Accuracy: 0.5663, Val Loss: 0.8781, Val Accuracy: 0.5911
# ===== Epoch 231/2000 =====
# No improvement in Val ROC AUC for 8 epoch(s). Best is 0.7968. Train Loss: 0.8993, Train Accuracy: 0.5506, Val Loss: 0.8685, Val Accuracy: 0.5600
# ===== Epoch 232/2000 =====
# No improvement in Val ROC AUC for 9 epoch(s). Best is 0.7968. Train Loss: 0.9137, Train Accuracy: 0.5451, Val Loss: 0.8949, Val Accuracy: 0.5511
# ===== Epoch 233/2000 =====
# No improvement in Val ROC AUC for 10 epoch(s). Best is 0.7968. Train Loss: 0.9187, Train Accuracy: 0.5671, Val Loss: 0.8697, Val Accuracy: 0.6000
# ===== Epoch 234/2000 =====
# No improvement in Val ROC AUC for 11 epoch(s). Best is 0.7968. Train Loss: 0.8974, Train Accuracy: 0.5616, Val Loss: 0.8729, Val Accuracy: 0.5733
# ===== Epoch 235/2000 =====
# No improvement in Val ROC AUC for 12 epoch(s). Best is 0.7968. Train Loss: 0.9021, Train Accuracy: 0.5490, Val Loss: 0.8487, Val Accuracy: 0.6356
# ===== Epoch 236/2000 =====
# No improvement in Val ROC AUC for 13 epoch(s). Best is 0.7968. Train Loss: 0.8948, Train Accuracy: 0.5655, Val Loss: 0.8541, Val Accuracy: 0.6089
# ===== Epoch 237/2000 =====
# No improvement in Val ROC AUC for 14 epoch(s). Best is 0.7968. Train Loss: 0.9035, Train Accuracy: 0.5459, Val Loss: 0.9026, Val Accuracy: 0.6000
# ===== Epoch 238/2000 =====
# No improvement in Val ROC AUC for 15 epoch(s). Best is 0.7968. Train Loss: 0.9101, Train Accuracy: 0.5482, Val Loss: 0.8856, Val Accuracy: 0.6089
# ===== Epoch 239/2000 =====
# No improvement in Val ROC AUC for 16 epoch(s). Best is 0.7968. Train Loss: 0.8999, Train Accuracy: 0.5639, Val Loss: 0.8672, Val Accuracy: 0.5644
# ===== Epoch 240/2000 =====
# No improvement in Val ROC AUC for 17 epoch(s). Best is 0.7968. Train Loss: 0.9029, Train Accuracy: 0.5663, Val Loss: 0.8848, Val Accuracy: 0.5956
# ===== Epoch 241/2000 =====
# New best model saved with Val ROC AUC: 0.8046, Train Loss: 0.8919, Train Accuracy: 0.5788, Val Loss: 0.8216, Val Accuracy: 0.6089
# ===== Epoch 242/2000 =====
# No improvement in Val ROC AUC for 1 epoch(s). Best is 0.8046. Train Loss: 0.8883, Train Accuracy: 0.5671, Val Loss: 0.8718, Val Accuracy: 0.5556
# ===== Epoch 243/2000 =====
# No improvement in Val ROC AUC for 2 epoch(s). Best is 0.8046. Train Loss: 0.9018, Train Accuracy: 0.5529, Val Loss: 0.8558, Val Accuracy: 0.5733
# ===== Epoch 244/2000 =====
# No improvement in Val ROC AUC for 3 epoch(s). Best is 0.8046. Train Loss: 0.8843, Train Accuracy: 0.5608, Val Loss: 0.8637, Val Accuracy: 0.5600
# ===== Epoch 245/2000 =====
# No improvement in Val ROC AUC for 4 epoch(s). Best is 0.8046. Train Loss: 0.8830, Train Accuracy: 0.5639, Val Loss: 0.8877, Val Accuracy: 0.5467
# ===== Epoch 246/2000 =====
# No improvement in Val ROC AUC for 5 epoch(s). Best is 0.8046. Train Loss: 0.8922, Train Accuracy: 0.5835, Val Loss: 0.8697, Val Accuracy: 0.5867
# ===== Epoch 247/2000 =====
# No improvement in Val ROC AUC for 6 epoch(s). Best is 0.8046. Train Loss: 0.8862, Train Accuracy: 0.5671, Val Loss: 0.8395, Val Accuracy: 0.6222
# ===== Epoch 248/2000 =====
# No improvement in Val ROC AUC for 7 epoch(s). Best is 0.8046. Train Loss: 0.8983, Train Accuracy: 0.5686, Val Loss: 0.8431, Val Accuracy: 0.6044
# ===== Epoch 249/2000 =====
# No improvement in Val ROC AUC for 8 epoch(s). Best is 0.8046. Train Loss: 0.8774, Train Accuracy: 0.5820, Val Loss: 0.8711, Val Accuracy: 0.6044
# ===== Epoch 250/2000 =====
# No improvement in Val ROC AUC for 9 epoch(s). Best is 0.8046. Train Loss: 0.8935, Train Accuracy: 0.5694, Val Loss: 0.9139, Val Accuracy: 0.5244
# ===== Epoch 251/2000 =====
# No improvement in Val ROC AUC for 10 epoch(s). Best is 0.8046. Train Loss: 0.8939, Train Accuracy: 0.5655, Val Loss: 0.8326, Val Accuracy: 0.6178
# ===== Epoch 252/2000 =====
# No improvement in Val ROC AUC for 11 epoch(s). Best is 0.8046. Train Loss: 0.8955, Train Accuracy: 0.5576, Val Loss: 0.8874, Val Accuracy: 0.5689
# ===== Epoch 253/2000 =====
# No improvement in Val ROC AUC for 12 epoch(s). Best is 0.8046. Train Loss: 0.8849, Train Accuracy: 0.5804, Val Loss: 0.8775, Val Accuracy: 0.5733
# ===== Epoch 254/2000 =====
# No improvement in Val ROC AUC for 13 epoch(s). Best is 0.8046. Train Loss: 0.8841, Train Accuracy: 0.5780, Val Loss: 0.8763, Val Accuracy: 0.5600
# ===== Epoch 255/2000 =====
# No improvement in Val ROC AUC for 14 epoch(s). Best is 0.8046. Train Loss: 0.8813, Train Accuracy: 0.5827, Val Loss: 0.8768, Val Accuracy: 0.5689
# ===== Epoch 256/2000 =====
# No improvement in Val ROC AUC for 15 epoch(s). Best is 0.8046. Train Loss: 0.8891, Train Accuracy: 0.5694, Val Loss: 0.9022, Val Accuracy: 0.5511
# ===== Epoch 257/2000 =====
# No improvement in Val ROC AUC for 16 epoch(s). Best is 0.8046. Train Loss: 0.8931, Train Accuracy: 0.5749, Val Loss: 0.8620, Val Accuracy: 0.5689
# ===== Epoch 258/2000 =====
# No improvement in Val ROC AUC for 17 epoch(s). Best is 0.8046. Train Loss: 0.8834, Train Accuracy: 0.5812, Val Loss: 0.8684, Val Accuracy: 0.5822
# ===== Epoch 259/2000 =====
# No improvement in Val ROC AUC for 18 epoch(s). Best is 0.8046. Train Loss: 0.9040, Train Accuracy: 0.5741, Val Loss: 0.8376, Val Accuracy: 0.6044
# ===== Epoch 260/2000 =====
# No improvement in Val ROC AUC for 19 epoch(s). Best is 0.8046. Train Loss: 0.8932, Train Accuracy: 0.5569, Val Loss: 0.8739, Val Accuracy: 0.5556
# ===== Epoch 261/2000 =====
# No improvement in Val ROC AUC for 20 epoch(s). Best is 0.8046. Train Loss: 0.9099, Train Accuracy: 0.5671, Val Loss: 0.8395, Val Accuracy: 0.6178
# ===== Epoch 262/2000 =====
# No improvement in Val ROC AUC for 21 epoch(s). Best is 0.8046. Train Loss: 0.8802, Train Accuracy: 0.5976, Val Loss: 0.8646, Val Accuracy: 0.5556
# ===== Epoch 263/2000 =====
# No improvement in Val ROC AUC for 22 epoch(s). Best is 0.8046. Train Loss: 0.8982, Train Accuracy: 0.5725, Val Loss: 0.8397, Val Accuracy: 0.6311
# ===== Epoch 264/2000 =====
# No improvement in Val ROC AUC for 23 epoch(s). Best is 0.8046. Train Loss: 0.8890, Train Accuracy: 0.5741, Val Loss: 0.8595, Val Accuracy: 0.6000
# ===== Epoch 265/2000 =====
# No improvement in Val ROC AUC for 24 epoch(s). Best is 0.8046. Train Loss: 0.8839, Train Accuracy: 0.5765, Val Loss: 0.8510, Val Accuracy: 0.6222
# ===== Epoch 266/2000 =====
# No improvement in Val ROC AUC for 25 epoch(s). Best is 0.8046. Train Loss: 0.9020, Train Accuracy: 0.5553, Val Loss: 0.8476, Val Accuracy: 0.5822
# ===== Epoch 267/2000 =====
# No improvement in Val ROC AUC for 26 epoch(s). Best is 0.8046. Train Loss: 0.8953, Train Accuracy: 0.5741, Val Loss: 0.8680, Val Accuracy: 0.5911
# ===== Epoch 268/2000 =====
# No improvement in Val ROC AUC for 27 epoch(s). Best is 0.8046. Train Loss: 0.8885, Train Accuracy: 0.5710, Val Loss: 0.8611, Val Accuracy: 0.5867
# ===== Epoch 269/2000 =====
# No improvement in Val ROC AUC for 28 epoch(s). Best is 0.8046. Train Loss: 0.8937, Train Accuracy: 0.5678, Val Loss: 0.8504, Val Accuracy: 0.5733
# ===== Epoch 270/2000 =====
# No improvement in Val ROC AUC for 29 epoch(s). Best is 0.8046. Train Loss: 0.9041, Train Accuracy: 0.5608, Val Loss: 0.8626, Val Accuracy: 0.5778
# ===== Epoch 271/2000 =====
# No improvement in Val ROC AUC for 30 epoch(s). Best is 0.8046. Train Loss: 0.9103, Train Accuracy: 0.5451, Val Loss: 0.8703, Val Accuracy: 0.6000
# ===== Epoch 272/2000 =====
# No improvement in Val ROC AUC for 31 epoch(s). Best is 0.8046. Train Loss: 0.8980, Train Accuracy: 0.5733, Val Loss: 0.8654, Val Accuracy: 0.5644
# ===== Epoch 273/2000 =====
# No improvement in Val ROC AUC for 32 epoch(s). Best is 0.8046. Train Loss: 0.8907, Train Accuracy: 0.5537, Val Loss: 0.8854, Val Accuracy: 0.5867
# ===== Epoch 274/2000 =====
# No improvement in Val ROC AUC for 33 epoch(s). Best is 0.8046. Train Loss: 0.8863, Train Accuracy: 0.5616, Val Loss: 0.9251, Val Accuracy: 0.5200
# ===== Epoch 275/2000 =====
# No improvement in Val ROC AUC for 34 epoch(s). Best is 0.8046. Train Loss: 0.9188, Train Accuracy: 0.5475, Val Loss: 0.8800, Val Accuracy: 0.6000
# ===== Epoch 276/2000 =====
# No improvement in Val ROC AUC for 35 epoch(s). Best is 0.8046. Train Loss: 0.8989, Train Accuracy: 0.5671, Val Loss: 0.8285, Val Accuracy: 0.5956
# ===== Epoch 277/2000 =====
# No improvement in Val ROC AUC for 36 epoch(s). Best is 0.8046. Train Loss: 0.9090, Train Accuracy: 0.5498, Val Loss: 0.9026, Val Accuracy: 0.5733
# ===== Epoch 278/2000 =====
# No improvement in Val ROC AUC for 37 epoch(s). Best is 0.8046. Train Loss: 0.8928, Train Accuracy: 0.5694, Val Loss: 0.8608, Val Accuracy: 0.5733
# ===== Epoch 279/2000 =====
# ...
# ===== Epoch 1910/2000 =====
# No improvement in Val ROC AUC for 173 epoch(s). Best is 0.9601. Train Loss: 0.6156, Train Accuracy: 0.8047, Val Loss: 0.5769, Val Accuracy: 0.8222
# ===== Epoch 1911/2000 =====
# No improvement in Val ROC AUC for 174 epoch(s). Best is 0.9601. Train Loss: 0.6155, Train Accuracy: 0.7875, Val Loss: 0.5964, Val Accuracy: 0.7911
# ===== Epoch 1912/2000 =====
# No improvement in Val ROC AUC for 175 epoch(s). Best is 0.9601. Train Loss: 0.6297, Train Accuracy: 0.7733, Val Loss: 0.5853, Val Accuracy: 0.7956
# ===== Epoch 1913/2000 =====
# No improvement in Val ROC AUC for 176 epoch(s). Best is 0.9601. Train Loss: 0.6287, Train Accuracy: 0.7757, Val Loss: 0.5509, Val Accuracy: 0.8356
# ===== Epoch 1914/2000 =====
# No improvement in Val ROC AUC for 177 epoch(s). Best is 0.9601. Train Loss: 0.6197, Train Accuracy: 0.7984, Val Loss: 0.6015, Val Accuracy: 0.7956
# ===== Epoch 1915/2000 =====
# No improvement in Val ROC AUC for 178 epoch(s). Best is 0.9601. Train Loss: 0.6106, Train Accuracy: 0.8024, Val Loss: 0.5920, Val Accuracy: 0.8178
# ===== Epoch 1916/2000 =====
# No improvement in Val ROC AUC for 179 epoch(s). Best is 0.9601. Train Loss: 0.6230, Train Accuracy: 0.8024, Val Loss: 0.5940, Val Accuracy: 0.7911
# ===== Epoch 1917/2000 =====
# No improvement in Val ROC AUC for 180 epoch(s). Best is 0.9601. Train Loss: 0.6190, Train Accuracy: 0.7984, Val Loss: 0.5944, Val Accuracy: 0.7956
# ===== Epoch 1918/2000 =====
# No improvement in Val ROC AUC for 181 epoch(s). Best is 0.9601. Train Loss: 0.6072, Train Accuracy: 0.8055, Val Loss: 0.6209, Val Accuracy: 0.7867
# ===== Epoch 1919/2000 =====
# No improvement in Val ROC AUC for 182 epoch(s). Best is 0.9601. Train Loss: 0.6127, Train Accuracy: 0.8031, Val Loss: 0.6278, Val Accuracy: 0.7911
# ===== Epoch 1920/2000 =====
# No improvement in Val ROC AUC for 183 epoch(s). Best is 0.9601. Train Loss: 0.6124, Train Accuracy: 0.7984, Val Loss: 0.5634, Val Accuracy: 0.8178
# ===== Epoch 1921/2000 =====
# No improvement in Val ROC AUC for 184 epoch(s). Best is 0.9601. Train Loss: 0.6100, Train Accuracy: 0.7976, Val Loss: 0.5556, Val Accuracy: 0.8178
# ===== Epoch 1922/2000 =====
# No improvement in Val ROC AUC for 185 epoch(s). Best is 0.9601. Train Loss: 0.6196, Train Accuracy: 0.7867, Val Loss: 0.5828, Val Accuracy: 0.8222
# ===== Epoch 1923/2000 =====
# No improvement in Val ROC AUC for 186 epoch(s). Best is 0.9601. Train Loss: 0.6221, Train Accuracy: 0.7906, Val Loss: 0.5924, Val Accuracy: 0.8133
# ===== Epoch 1924/2000 =====
# No improvement in Val ROC AUC for 187 epoch(s). Best is 0.9601. Train Loss: 0.6076, Train Accuracy: 0.7976, Val Loss: 0.5888, Val Accuracy: 0.8178
# ===== Epoch 1925/2000 =====
# No improvement in Val ROC AUC for 188 epoch(s). Best is 0.9601. Train Loss: 0.6045, Train Accuracy: 0.8094, Val Loss: 0.5751, Val Accuracy: 0.8356
# ===== Epoch 1926/2000 =====
# No improvement in Val ROC AUC for 189 epoch(s). Best is 0.9601. Train Loss: 0.6004, Train Accuracy: 0.8071, Val Loss: 0.5626, Val Accuracy: 0.8356
# ===== Epoch 1927/2000 =====
# No improvement in Val ROC AUC for 190 epoch(s). Best is 0.9601. Train Loss: 0.6062, Train Accuracy: 0.7969, Val Loss: 0.5849, Val Accuracy: 0.8178
# ===== Epoch 1928/2000 =====
# No improvement in Val ROC AUC for 191 epoch(s). Best is 0.9601. Train Loss: 0.6062, Train Accuracy: 0.7992, Val Loss: 0.5510, Val Accuracy: 0.8578
# ===== Epoch 1929/2000 =====
# No improvement in Val ROC AUC for 192 epoch(s). Best is 0.9601. Train Loss: 0.6141, Train Accuracy: 0.7984, Val Loss: 0.5947, Val Accuracy: 0.8133
# ===== Epoch 1930/2000 =====
# No improvement in Val ROC AUC for 193 epoch(s). Best is 0.9601. Train Loss: 0.6088, Train Accuracy: 0.8031, Val Loss: 0.5863, Val Accuracy: 0.8133
# ===== Epoch 1931/2000 =====
# No improvement in Val ROC AUC for 194 epoch(s). Best is 0.9601. Train Loss: 0.5935, Train Accuracy: 0.8125, Val Loss: 0.5765, Val Accuracy: 0.8311
# ===== Epoch 1932/2000 =====
# No improvement in Val ROC AUC for 195 epoch(s). Best is 0.9601. Train Loss: 0.6066, Train Accuracy: 0.8047, Val Loss: 0.5613, Val Accuracy: 0.8622
# ===== Epoch 1933/2000 =====
# No improvement in Val ROC AUC for 196 epoch(s). Best is 0.9601. Train Loss: 0.5966, Train Accuracy: 0.8063, Val Loss: 0.5601, Val Accuracy: 0.8311
# ===== Epoch 1934/2000 =====
# No improvement in Val ROC AUC for 197 epoch(s). Best is 0.9601. Train Loss: 0.6071, Train Accuracy: 0.8016, Val Loss: 0.5779, Val Accuracy: 0.8222
# ===== Epoch 1935/2000 =====
# No improvement in Val ROC AUC for 198 epoch(s). Best is 0.9601. Train Loss: 0.5866, Train Accuracy: 0.8196, Val Loss: 0.5783, Val Accuracy: 0.8356
# ===== Epoch 1936/2000 =====
# No improvement in Val ROC AUC for 199 epoch(s). Best is 0.9601. Train Loss: 0.5922, Train Accuracy: 0.8071, Val Loss: 0.5830, Val Accuracy: 0.8133
# ===== Epoch 1937/2000 =====
# No improvement in Val ROC AUC for 200 epoch(s). Best is 0.9601. Train Loss: 0.6014, Train Accuracy: 0.8118, Val Loss: 0.5493, Val Accuracy: 0.8444
# ===== Epoch 1938/2000 =====
# No improvement in Val ROC AUC for 201 epoch(s). Best is 0.9601. Train Loss: 0.5989, Train Accuracy: 0.8102, Val Loss: 0.5624, Val Accuracy: 0.8400
# ===== Epoch 1939/2000 =====
# No improvement in Val ROC AUC for 202 epoch(s). Best is 0.9601. Train Loss: 0.5920, Train Accuracy: 0.7992, Val Loss: 0.5936, Val Accuracy: 0.8133
# ===== Epoch 1940/2000 =====
# No improvement in Val ROC AUC for 203 epoch(s). Best is 0.9601. Train Loss: 0.5779, Train Accuracy: 0.8345, Val Loss: 0.5633, Val Accuracy: 0.8356
# ===== Epoch 1941/2000 =====
# No improvement in Val ROC AUC for 204 epoch(s). Best is 0.9601. Train Loss: 0.5983, Train Accuracy: 0.8094, Val Loss: 0.5404, Val Accuracy: 0.8489
# ===== Epoch 1942/2000 =====
# No improvement in Val ROC AUC for 205 epoch(s). Best is 0.9601. Train Loss: 0.5751, Train Accuracy: 0.8282, Val Loss: 0.5644, Val Accuracy: 0.8400
# ===== Epoch 1943/2000 =====
# No improvement in Val ROC AUC for 206 epoch(s). Best is 0.9601. Train Loss: 0.5876, Train Accuracy: 0.8086, Val Loss: 0.5587, Val Accuracy: 0.8444
# ===== Epoch 1944/2000 =====
# No improvement in Val ROC AUC for 207 epoch(s). Best is 0.9601. Train Loss: 0.6044, Train Accuracy: 0.7992, Val Loss: 0.5629, Val Accuracy: 0.8622
# ===== Epoch 1945/2000 =====
# No improvement in Val ROC AUC for 208 epoch(s). Best is 0.9601. Train Loss: 0.6000, Train Accuracy: 0.8188, Val Loss: 0.5384, Val Accuracy: 0.8356
# ===== Epoch 1946/2000 =====
# No improvement in Val ROC AUC for 209 epoch(s). Best is 0.9601. Train Loss: 0.5819, Train Accuracy: 0.8243, Val Loss: 0.5460, Val Accuracy: 0.8533
# ===== Epoch 1947/2000 =====
# No improvement in Val ROC AUC for 210 epoch(s). Best is 0.9601. Train Loss: 0.5960, Train Accuracy: 0.8173, Val Loss: 0.5395, Val Accuracy: 0.8622
# ===== Epoch 1948/2000 =====
# No improvement in Val ROC AUC for 211 epoch(s). Best is 0.9601. Train Loss: 0.5983, Train Accuracy: 0.8118, Val Loss: 0.5780, Val Accuracy: 0.8044
# ===== Epoch 1949/2000 =====
# No improvement in Val ROC AUC for 212 epoch(s). Best is 0.9601. Train Loss: 0.5807, Train Accuracy: 0.8078, Val Loss: 0.5641, Val Accuracy: 0.8533
# ===== Epoch 1950/2000 =====
# No improvement in Val ROC AUC for 213 epoch(s). Best is 0.9601. Train Loss: 0.6015, Train Accuracy: 0.8094, Val Loss: 0.6016, Val Accuracy: 0.8000
# ===== Epoch 1951/2000 =====
# No improvement in Val ROC AUC for 214 epoch(s). Best is 0.9601. Train Loss: 0.6001, Train Accuracy: 0.8031, Val Loss: 0.5490, Val Accuracy: 0.8356
# ===== Epoch 1952/2000 =====
# No improvement in Val ROC AUC for 215 epoch(s). Best is 0.9601. Train Loss: 0.6007, Train Accuracy: 0.8078, Val Loss: 0.5942, Val Accuracy: 0.8222
# ===== Epoch 1953/2000 =====
# No improvement in Val ROC AUC for 216 epoch(s). Best is 0.9601. Train Loss: 0.5946, Train Accuracy: 0.8227, Val Loss: 0.5701, Val Accuracy: 0.8133
# ===== Epoch 1954/2000 =====
# No improvement in Val ROC AUC for 217 epoch(s). Best is 0.9601. Train Loss: 0.5991, Train Accuracy: 0.8118, Val Loss: 0.5612, Val Accuracy: 0.8356
# ===== Epoch 1955/2000 =====
# No improvement in Val ROC AUC for 218 epoch(s). Best is 0.9601. Train Loss: 0.6013, Train Accuracy: 0.8149, Val Loss: 0.5625, Val Accuracy: 0.8400
# ===== Epoch 1956/2000 =====
# No improvement in Val ROC AUC for 219 epoch(s). Best is 0.9601. Train Loss: 0.5871, Train Accuracy: 0.8212, Val Loss: 0.5927, Val Accuracy: 0.8267
# ===== Epoch 1957/2000 =====
# No improvement in Val ROC AUC for 220 epoch(s). Best is 0.9601. Train Loss: 0.5994, Train Accuracy: 0.8039, Val Loss: 0.5577, Val Accuracy: 0.8533
# ===== Epoch 1958/2000 =====
# No improvement in Val ROC AUC for 221 epoch(s). Best is 0.9601. Train Loss: 0.5861, Train Accuracy: 0.8165, Val Loss: 0.5663, Val Accuracy: 0.8533
# ===== Epoch 1959/2000 =====
# No improvement in Val ROC AUC for 222 epoch(s). Best is 0.9601. Train Loss: 0.6118, Train Accuracy: 0.8008, Val Loss: 0.5881, Val Accuracy: 0.7911
# ===== Epoch 1960/2000 =====
# No improvement in Val ROC AUC for 223 epoch(s). Best is 0.9601. Train Loss: 0.6073, Train Accuracy: 0.7937, Val Loss: 0.5503, Val Accuracy: 0.8444
# ===== Epoch 1961/2000 =====
# No improvement in Val ROC AUC for 224 epoch(s). Best is 0.9601. Train Loss: 0.5905, Train Accuracy: 0.8188, Val Loss: 0.6122, Val Accuracy: 0.7822
# ===== Epoch 1962/2000 =====
# No improvement in Val ROC AUC for 225 epoch(s). Best is 0.9601. Train Loss: 0.6218, Train Accuracy: 0.7851, Val Loss: 0.6149, Val Accuracy: 0.8178
# ===== Epoch 1963/2000 =====
# No improvement in Val ROC AUC for 226 epoch(s). Best is 0.9601. Train Loss: 0.6012, Train Accuracy: 0.7984, Val Loss: 0.5869, Val Accuracy: 0.8089
# ===== Epoch 1964/2000 =====
# No improvement in Val ROC AUC for 227 epoch(s). Best is 0.9601. Train Loss: 0.5893, Train Accuracy: 0.8306, Val Loss: 0.5926, Val Accuracy: 0.8133
# ===== Epoch 1965/2000 =====
# No improvement in Val ROC AUC for 228 epoch(s). Best is 0.9601. Train Loss: 0.6141, Train Accuracy: 0.8016, Val Loss: 0.5962, Val Accuracy: 0.7778
# ===== Epoch 1966/2000 =====
# No improvement in Val ROC AUC for 229 epoch(s). Best is 0.9601. Train Loss: 0.6023, Train Accuracy: 0.8110, Val Loss: 0.6197, Val Accuracy: 0.7867
# ===== Epoch 1967/2000 =====
# No improvement in Val ROC AUC for 230 epoch(s). Best is 0.9601. Train Loss: 0.6195, Train Accuracy: 0.7890, Val Loss: 0.5533, Val Accuracy: 0.8533
# ===== Epoch 1968/2000 =====
# No improvement in Val ROC AUC for 231 epoch(s). Best is 0.9601. Train Loss: 0.6133, Train Accuracy: 0.7984, Val Loss: 0.5790, Val Accuracy: 0.8267
# ===== Epoch 1969/2000 =====
# No improvement in Val ROC AUC for 232 epoch(s). Best is 0.9601. Train Loss: 0.6130, Train Accuracy: 0.7992, Val Loss: 0.6099, Val Accuracy: 0.8133
# ===== Epoch 1970/2000 =====
# No improvement in Val ROC AUC for 233 epoch(s). Best is 0.9601. Train Loss: 0.6225, Train Accuracy: 0.7859, Val Loss: 0.6125, Val Accuracy: 0.7778
# ===== Epoch 1971/2000 =====
# No improvement in Val ROC AUC for 234 epoch(s). Best is 0.9601. Train Loss: 0.6291, Train Accuracy: 0.7718, Val Loss: 0.5956, Val Accuracy: 0.7956
# ===== Epoch 1972/2000 =====
# No improvement in Val ROC AUC for 235 epoch(s). Best is 0.9601. Train Loss: 0.6255, Train Accuracy: 0.7914, Val Loss: 0.6127, Val Accuracy: 0.7733
# ===== Epoch 1973/2000 =====
# No improvement in Val ROC AUC for 236 epoch(s). Best is 0.9601. Train Loss: 0.6280, Train Accuracy: 0.7804, Val Loss: 0.6010, Val Accuracy: 0.8044
# ===== Epoch 1974/2000 =====
# No improvement in Val ROC AUC for 237 epoch(s). Best is 0.9601. Train Loss: 0.6376, Train Accuracy: 0.7780, Val Loss: 0.5843, Val Accuracy: 0.8489
# ===== Epoch 1975/2000 =====
# No improvement in Val ROC AUC for 238 epoch(s). Best is 0.9601. Train Loss: 0.6189, Train Accuracy: 0.7859, Val Loss: 0.6005, Val Accuracy: 0.8267
# ===== Epoch 1976/2000 =====
# No improvement in Val ROC AUC for 239 epoch(s). Best is 0.9601. Train Loss: 0.6476, Train Accuracy: 0.7694, Val Loss: 0.6946, Val Accuracy: 0.7333
# ===== Epoch 1977/2000 =====
# No improvement in Val ROC AUC for 240 epoch(s). Best is 0.9601. Train Loss: 0.6463, Train Accuracy: 0.7796, Val Loss: 0.6062, Val Accuracy: 0.8089
# ===== Epoch 1978/2000 =====
# No improvement in Val ROC AUC for 241 epoch(s). Best is 0.9601. Train Loss: 0.6284, Train Accuracy: 0.7859, Val Loss: 0.6091, Val Accuracy: 0.7911
# ===== Epoch 1979/2000 =====
# No improvement in Val ROC AUC for 242 epoch(s). Best is 0.9601. Train Loss: 0.6269, Train Accuracy: 0.7835, Val Loss: 0.5636, Val Accuracy: 0.8356
# ===== Epoch 1980/2000 =====
# No improvement in Val ROC AUC for 243 epoch(s). Best is 0.9601. Train Loss: 0.6118, Train Accuracy: 0.7898, Val Loss: 0.6193, Val Accuracy: 0.7778
# ===== Epoch 1981/2000 =====
# No improvement in Val ROC AUC for 244 epoch(s). Best is 0.9601. Train Loss: 0.6191, Train Accuracy: 0.7922, Val Loss: 0.6182, Val Accuracy: 0.8133
# ===== Epoch 1982/2000 =====
# No improvement in Val ROC AUC for 245 epoch(s). Best is 0.9601. Train Loss: 0.6578, Train Accuracy: 0.7498, Val Loss: 0.6081, Val Accuracy: 0.8089
# ===== Epoch 1983/2000 =====
# No improvement in Val ROC AUC for 246 epoch(s). Best is 0.9601. Train Loss: 0.6258, Train Accuracy: 0.7702, Val Loss: 0.5960, Val Accuracy: 0.8133
# ===== Epoch 1984/2000 =====
# No improvement in Val ROC AUC for 247 epoch(s). Best is 0.9601. Train Loss: 0.6194, Train Accuracy: 0.7898, Val Loss: 0.5884, Val Accuracy: 0.8044
# ===== Epoch 1985/2000 =====
# No improvement in Val ROC AUC for 248 epoch(s). Best is 0.9601. Train Loss: 0.6384, Train Accuracy: 0.7804, Val Loss: 0.5959, Val Accuracy: 0.8444
# ===== Epoch 1986/2000 =====
# No improvement in Val ROC AUC for 249 epoch(s). Best is 0.9601. Train Loss: 0.6079, Train Accuracy: 0.7992, Val Loss: 0.6205, Val Accuracy: 0.8000
# ===== Epoch 1987/2000 =====
# No improvement in Val ROC AUC for 250 epoch(s). Best is 0.9601. Train Loss: 0.6395, Train Accuracy: 0.7773, Val Loss: 0.5814, Val Accuracy: 0.8089
# ===== Epoch 1988/2000 =====
# No improvement in Val ROC AUC for 251 epoch(s). Best is 0.9601. Train Loss: 0.6314, Train Accuracy: 0.7749, Val Loss: 0.6125, Val Accuracy: 0.7778
# ===== Epoch 1989/2000 =====
# No improvement in Val ROC AUC for 252 epoch(s). Best is 0.9601. Train Loss: 0.6296, Train Accuracy: 0.7890, Val Loss: 0.6093, Val Accuracy: 0.7911
# ===== Epoch 1990/2000 =====
# No improvement in Val ROC AUC for 253 epoch(s). Best is 0.9601. Train Loss: 0.6279, Train Accuracy: 0.7725, Val Loss: 0.6133, Val Accuracy: 0.7911
# ===== Epoch 1991/2000 =====
# No improvement in Val ROC AUC for 254 epoch(s). Best is 0.9601. Train Loss: 0.6305, Train Accuracy: 0.7827, Val Loss: 0.5957, Val Accuracy: 0.8089
# ===== Epoch 1992/2000 =====
# No improvement in Val ROC AUC for 255 epoch(s). Best is 0.9601. Train Loss: 0.6314, Train Accuracy: 0.7788, Val Loss: 0.5876, Val Accuracy: 0.8267
# ===== Epoch 1993/2000 =====
# No improvement in Val ROC AUC for 256 epoch(s). Best is 0.9601. Train Loss: 0.6319, Train Accuracy: 0.7890, Val Loss: 0.5788, Val Accuracy: 0.8622
# ===== Epoch 1994/2000 =====
# No improvement in Val ROC AUC for 257 epoch(s). Best is 0.9601. Train Loss: 0.6243, Train Accuracy: 0.7859, Val Loss: 0.5809, Val Accuracy: 0.8178
# ===== Epoch 1995/2000 =====
# No improvement in Val ROC AUC for 258 epoch(s). Best is 0.9601. Train Loss: 0.6218, Train Accuracy: 0.7898, Val Loss: 0.6592, Val Accuracy: 0.7556
# ===== Epoch 1996/2000 =====
# No improvement in Val ROC AUC for 259 epoch(s). Best is 0.9601. Train Loss: 0.6478, Train Accuracy: 0.7733, Val Loss: 0.6331, Val Accuracy: 0.7867
# ===== Epoch 1997/2000 =====
# No improvement in Val ROC AUC for 260 epoch(s). Best is 0.9601. Train Loss: 0.6272, Train Accuracy: 0.7859, Val Loss: 0.6257, Val Accuracy: 0.7867
# ===== Epoch 1998/2000 =====
# No improvement in Val ROC AUC for 261 epoch(s). Best is 0.9601. Train Loss: 0.6328, Train Accuracy: 0.7757, Val Loss: 0.6086, Val Accuracy: 0.8222
# ===== Epoch 1999/2000 =====
# No improvement in Val ROC AUC for 262 epoch(s). Best is 0.9601. Train Loss: 0.6314, Train Accuracy: 0.7875, Val Loss: 0.6130, Val Accuracy: 0.8178
# ===== Epoch 2000/2000 =====
# No improvement in Val ROC AUC for 263 epoch(s). Best is 0.9601. Train Loss: 0.6473, Train Accuracy: 0.7773, Val Loss: 0.5808, Val Accuracy: 0.8133
#
# Training Complete!
#
# ROC curve plot saved as roc_curve.png

# %% [markdown]
# """ ROC Curve Plotting Function"""
# def plot_roc_curve(all_preds, all_labels):
#     print("Generating ROC Curve")
#
#     # Convert predictions and labels to numpy arrays
#     all_preds = np.array(all_preds)
#     all_labels = np.array(all_labels)
#
#     fpr = dict()
#     tpr = dict()
#     roc_auc = dict()
#     n_classes = 3
#
#     for i in range(n_classes):
#         fpr[i], tpr[i], _ = roc_curve((all_labels == i).astype(int), all_preds[:, i])
#         roc_auc[i] = auc(fpr[i], tpr[i])
#
#         print(f"Class {i} ROC AUC: {roc_auc[i]:.4f}")
#
#     # Plot ROC curves
#     plt.figure(figsize=(10, 8))
#     colors = ['blue', 'red', 'green']
#     class_names = ['Axion', 'CDM', 'No Substructure']
#
#     for i, color in zip(range(n_classes), colors):
#         plt.plot(fpr[i], tpr[i], color=color,
#                  label=f'{class_names[i]} (AUC = {roc_auc[i]:.2f})')
#
#     plt.plot([0, 1], [0, 1], 'k--')
#     plt.xlim([0.0, 1.0])
#     plt.ylim([0.0, 1.05])
#     plt.xlabel('False Positive Rate')
#     plt.ylabel('True Positive Rate')
#     plt.title('Receiver Operating Characteristic (ROC) Curve')
#     plt.legend(loc="lower right")
#     plt.savefig('/content/drive/MyDrive/Model_III_dataset/roc_curve_heal_swin_pinn.png')
#     plt.close()
#
#     print("ROC Curve saved as roc_curve.png")
#
#
# plot_roc_curve(all_probs, all_labels)
#
# print("Training and Evaluation Complete!")
